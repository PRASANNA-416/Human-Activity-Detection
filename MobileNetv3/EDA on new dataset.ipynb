# %%
import pandas as pd 
df = pd.read_csv('C:/Users/Prasanna P M/Human Project/Project U Turn/filtered_imp_data.csv')

# %%
df.head()
# Out:
#    ID           NAME Activity                Category
# 0   8  021233911.jpg  sitting  inactivity quiet/light
# 1   9  018182497.jpg  sitting  inactivity quiet/light
# 2  10  018340451.jpg  sitting           miscellaneous
# 3  11  030424224.jpg  sitting           miscellaneous
# 4  12  052475643.jpg  sitting           miscellaneous

# %%
df.shape
# Out:
# (8301, 4)

# %%
activity_counts = df['Activity'].value_counts()

# Get the top 70 activities based on highest occurrence counts
top_activities = activity_counts.head(49)

# Print each activity key and its occurrence count
for activity, count in top_activities.items():
    print(f"{activity}\t \t \t \t {count}")
# Out:
# bicycling	 	 	 	 598
# fishing	 	 	 	 472
# standing	 	 	 	 439
# skiing	 	 	 	 355
# yoga	 	 	 	 340
# dancing	 	 	 	 338
# gardening	 	 	 	 323
# running	 	 	 	 278
# carpentry refinishing cabinets	 	 	 	 262
# cooking or food preparation	 	 	 	 206
# soccer	 	 	 	 193
# skateboarding	 	 	 	 184
# swimming	 	 	 	 175
# softball, general	 	 	 	 173
# painting	 	 	 	 171
# playing playing basketball	 	 	 	 170
# ballet modern jazz	 	 	 	 156
# walking	 	 	 	 155
# rope skipping	 	 	 	 155
# farming	 	 	 	 155
# playing tennis	 	 	 	 153
# video exercise workouts	 	 	 	 151
# rowing	 	 	 	 150
# sitting	 	 	 	 145
# rock climbing	 	 	 	 145
# circuit training	 	 	 	 141
# golf	 	 	 	 138
# horseback riding	 	 	 	 131
# martial arts	 	 	 	 129
# hunting	 	 	 	 122
# calisthenics	 	 	 	 114
# cleaning	 	 	 	 111
# tailoring	 	 	 	 110
# backpacking	 	 	 	 105
# playing with animals	 	 	 	 93
# volleyball	 	 	 	 92
# rollerblading	 	 	 	 89
# frisbee	 	 	 	 87
# chopping wood	 	 	 	 86
# ...

# %%
import os

# Activity names
activity_names = [
    'bicycling',
    'fishing',
    'standing',
    'skiing',
    'yoga',
    'dancing',
    'gardening',
    'running',
    'carpentry refinishing cabinets',
    'cooking or food preparation',
    'soccer',
    'skateboarding',
    'swimming',
    'softball, general',
    'painting',
    'playing playing basketball',
    'ballet modern jazz',
    'walking',
    'rope skipping',
    'farming',
    'playing tennis',
    'video exercise workouts',
    'rowing',
    'sitting',
    'rock climbing',
    'circuit training',
    'golf',
    'horseback riding',
    'martial arts',
    'hunting',
    'calisthenics',
    'cleaning',
    'tailoring',
    'backpacking',
    'playing with animals',
    'volleyball',
    'rollerblading',
    'frisbee',
    'chopping wood',
    'washing and waxing car',
    'playing with children',
    'child care',
    'bakery',
    'home repair',
    'windsurfing',
    'eating',
    'squash',
    'cook',
    'massage therapist'
]

# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN/"

# Create subfolders based on activity names
for activity in activity_names:
    subfolder_path = os.path.join(main_directory, activity)
    os.makedirs(subfolder_path, exist_ok=True)

print("Subfolders created successfully!")
# Out:
# Subfolders created successfully!

# %%
import os
import shutil
import pandas as pd

# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN/"
data_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/Data/"
csv_file_path = "C:/Users/Prasanna P M/Human Project/Project U Turn/filtered_imp_data.csv"  # Replace with the actual path to your CSV file

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(csv_file_path)

# Iterate through each image in the "Data" folder
for filename in os.listdir(data_directory):
    image_path = os.path.join(data_directory, filename)
    if os.path.isfile(image_path):
        # Check if the image filename exists in the "Image filename" column of the CSV file
        matching_rows = df[df["NAME"] == filename]
        if not matching_rows.empty:
            activity_name = matching_rows.iloc[0]["Activity"]

            # Check if the activity name is one of the subfolders in the main directory
            activity_folder = os.path.join(main_directory, activity_name)
            if os.path.isdir(activity_folder):
                # Copy the image to the corresponding subfolder
                destination_path = os.path.join(activity_folder, filename)
                shutil.copy(image_path, destination_path)
                print(f"Image {filename} copied to {activity_folder}")

print("Image copying completed!")
# Out:
# Image 000003072.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN/rope skipping
# Image 000024100.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN/standing
# Image 000040154.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN/gardening
# Image 000041029.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN/cooking or food preparation
# Image 000065339.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN/chopping wood
# Image 000085370.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN/sitting
# Image 000109154.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN/carpentry refinishing cabinets
# Image 000111209.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN/rope skipping
# Image 000131987.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN/standing
# ...

# %%
# Out:
# Subdirectory: backpacking
# Total files: 210
#
# Subdirectory: bakery
# Total files: 142
#
# Subdirectory: ballet modern jazz
# Total files: 312
#
# Subdirectory: bicycling
# Total files: 1196
#
# Subdirectory: calisthenics
# Total files: 228
#
# Subdirectory: carpentry refinishing cabinets
# Total files: 524
#
# Subdirectory: child care
# Total files: 148
#
# Subdirectory: chopping wood
# Total files: 172
#
# Subdirectory: circuit training
# Total files: 282
#
# Subdirectory: cleaning
# Total files: 222
#
# Subdirectory: cook
# Total files: 132
#
# Subdirectory: cooking or food preparation
# Total files: 412
#
# Subdirectory: dancing
# Total files: 676
#
# Subdirectory: eating
# Total files: 136
#
# Subdirectory: farming
# Total files: 310
#
# Subdirectory: fishing
# Total files: 944
#
# Subdirectory: frisbee
# Total files: 174
#
# Subdirectory: gardening
# Total files: 646
#
# Subdirectory: golf
# Total files: 276
#
# Subdirectory: home repair
# Total files: 140
#
# ...

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import Image

# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN/"

# Data augmentation parameters
augmentation_params = {
    'rotation_range': 20,
    'width_shift_range': 0.2,
    'height_shift_range': 0.2,
    'shear_range': 0.2,
    'zoom_range': 0.2,
    'horizontal_flip': True
}

# Target image size
target_size = (224, 224)

# Iterate through each subdirectory
for subdirectory in os.listdir(main_directory):
    subdirectory_path = os.path.join(main_directory, subdirectory)
    
    if os.path.isdir(subdirectory_path):
        # Create an ImageDataGenerator with augmentation parameters
        datagen = ImageDataGenerator(**augmentation_params)
        
        # Get a list of image files within the subdirectory
        image_files = [filename for filename in os.listdir(subdirectory_path) if os.path.isfile(os.path.join(subdirectory_path, filename))]
        
        # Iterate through each image file and apply data augmentation
        for image_file in image_files:
            image_path = os.path.join(subdirectory_path, image_file)
            
            # Load the image
            image = Image.open(image_path)
            
            # Resize the image to the target size
            image = image.resize(target_size)
            
            # Convert the image to a NumPy array
            image_array = np.array(image)
            
            # Generate augmented image
            augmented_image = datagen.flow(image_array.reshape(1, *image_array.shape), batch_size=1).next()[0].astype(np.uint8)
            
            # Convert augmented image back to PIL image
            augmented_image = Image.fromarray(augmented_image)
            
            # Save the augmented image
            augmented_image_path = os.path.join(subdirectory_path, "augmented_" + image_file)
            augmented_image.save(augmented_image_path)

print("Data augmentation applied successfully!")
# Out:
# Data augmentation applied successfully!

# %%
import os
import numpy as np
import tensorflow as tf
from PIL import Image

# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN/"

# Data augmentation parameters
augmentation_params = {
    'brightness': 0.4,
    'contrast': 1.0,
    'jpeg_quality': [80, 100],
    'saturation': 0.5
}

# Target image size
target_size = (224, 224)

# Iterate through each subdirectory
for subdirectory in os.listdir(main_directory):
    subdirectory_path = os.path.join(main_directory, subdirectory)
    
    if os.path.isdir(subdirectory_path):
        # Get a list of image files within the subdirectory
        image_files = [filename for filename in os.listdir(subdirectory_path) if os.path.isfile(os.path.join(subdirectory_path, filename))]
        
        # Iterate through each image file and apply data augmentation
        for image_file in image_files:
            image_path = os.path.join(subdirectory_path, image_file)
            
            # Load and preprocess the image
            image = Image.open(image_path)
            image_tensor = tf.convert_to_tensor(np.array(image))
            image_tensor = tf.image.resize(image_tensor, target_size)
            image_tensor = tf.cast(image_tensor, tf.float32) / 255.0  # Normalize pixel values
            
            # Apply data augmentation
            augmented_image = tf.image.stateless_random_brightness(image_tensor, max_delta=augmentation_params['brightness'], seed=(1, 2))
            augmented_image = tf.image.stateless_random_contrast(augmented_image, lower=1 - augmentation_params['contrast'], upper=1 + augmentation_params['contrast'], seed=(1, 2))
            augmented_image = tf.image.stateless_random_jpeg_quality(augmented_image, min_jpeg_quality=augmentation_params['jpeg_quality'][0], max_jpeg_quality=augmentation_params['jpeg_quality'][1], seed=(1, 2))
            augmented_image = tf.image.stateless_random_saturation(augmented_image, lower=1 - augmentation_params['saturation'], upper=1 + augmentation_params['saturation'], seed=(1, 2))
            
            # Convert augmented image back to PIL image
            augmented_image = tf.clip_by_value(augmented_image * 255.0, 0.0, 255.0)
            augmented_image = tf.cast(augmented_image, tf.uint8)
            augmented_image = Image.fromarray(augmented_image.numpy())
            
            # Generate a new file name for the augmented image
            augmented_image_file = "col_" + image_file
            
            # Save the augmented image with the new file name
            augmented_image_path = os.path.join(subdirectory_path, augmented_image_file)
            augmented_image.save(augmented_image_path)

# %%
import os

# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN/"

# Iterate through each subdirectory
for subdirectory in os.listdir(main_directory):
    subdirectory_path = os.path.join(main_directory, subdirectory)
    
    if os.path.isdir(subdirectory_path):
        # Count the number of image files in the subdirectory
        # Count the total number of files in the subdirectory
        total_files = len(os.listdir(subdirectory_path))
        
        
        # Print the results
        print(f"Subdirectory: {subdirectory}")
        print(f"Total files: {total_files}")

        print()
# Out:
# Subdirectory: backpacking
# Total files: 420
#
# Subdirectory: bakery
# Total files: 284
#
# Subdirectory: ballet modern jazz
# Total files: 624
#
# Subdirectory: bicycling
# Total files: 2392
#
# Subdirectory: calisthenics
# Total files: 456
#
# Subdirectory: carpentry refinishing cabinets
# Total files: 1048
#
# Subdirectory: child care
# Total files: 296
#
# Subdirectory: chopping wood
# Total files: 344
#
# Subdirectory: circuit training
# Total files: 564
#
# Subdirectory: cleaning
# Total files: 444
#
# Subdirectory: cook
# Total files: 264
#
# Subdirectory: cooking or food preparation
# Total files: 824
#
# Subdirectory: dancing
# Total files: 1352
#
# Subdirectory: eating
# Total files: 272
#
# Subdirectory: farming
# Total files: 620
#
# Subdirectory: fishing
# Total files: 1888
#
# Subdirectory: frisbee
# Total files: 348
#
# Subdirectory: gardening
# Total files: 1292
#
# Subdirectory: golf
# Total files: 552
#
# Subdirectory: home repair
# Total files: 280
#
# ...

# %% [markdown]
# Subdirectory: backpacking
# Total files: 420
#
# Training - 336
# Validation - 42
# Test - 42
#
# ===============================================================================
#
# Subdirectory: bakery
# Total files: 284
#
# Training - 228
# Validation - 29
# Test - 27
#
# =====================================================================
#
# Subdirectory: ballet modern jazz
# Total files: 624
#
# Training- 500
#
# validation - 62
#
# Testing -  62
#
#
#
# ==========================================================================
#
# Subdirectory: bicycling
# Total files: 2392
#
#
# Training- 1914
#
# validation - 240
#
# Testing - 238
#
#
# ===========================================================================
#
# Subdirectory: calisthenics
# Total files: 456
#
# Training- 365
#
# validation - 46
#
# Testing - 45
#
#
#
# ===========================================================================
#
# Subdirectory: carpentry refinishing cabinets
# Total files: 1048
#
# Training- 839
#
# validation - 105
#
# Testing - 104
#
#
#
#
# =========================================================================
#
# Subdirectory: child care
# Total files: 296
#
# Training- 237
#
# validation - 29
#
# Testing - 30
#
#
# ===========================================================================
#
# Subdirectory: chopping wood
# Total files: 344
#
# Training- 276
#
# validation - 35
#
# Testing - 33
#
#
#
# ====================================================================
#
# Subdirectory: circuit training
# Total files: 564
#
# Training- 452
#
# validation - 57
#
# Testing - 55
#
#
#
#
# ======================================================================
#
# Subdirectory: cleaning
# Total files: 444
#
# Training- 356
#
# validation - 45
#
# Testing - 43
#
#
# =====================================================================
#
# Subdirectory: cook
# Total files: 264
#
# Training- 212
#
# validation - 27
#
# Testing - 25
#
#
#
# =======================================================================
#
# Subdirectory: cooking or food preparation
# Total files: 824
#
# Training- 660
#
# validation - 82
#
# Testing - 82
#
#
#
#
#
# =====================================================================
#
# Subdirectory: dancing
# Total files: 1352
#
#
# Training- 1082
#
# validation - 135
#
# Testing - 135
#
#
#
#
# ==================================================================
#
# Subdirectory: eating
# Total files: 272
#
# Training- 218
#
# validation - 27
#
# Testing - 27
#
#
# ======================================================================
#
# Subdirectory: farming
# Total files: 620
#
# Training- 496
#
# validation - 62
#
# Testing - 62
#
#
# ======================================================================
#
# Subdirectory: fishing
# Total files: 1888
#
# Training- 1511
#
# validation - 189
#
# Testing - 188
#
#
# ======================================================================
#
# Subdirectory: frisbee
# Total files: 348
#
# Training- 279
#
# validation - 34
#
# Testing - 35
#
#
# ======================================================================
#
# Subdirectory: gardening
# Total files: 1292
#
# Training- 1034
#
# validation - 129
#
# Testing - 129
#
#
# ======================================================================
#
# Subdirectory: golf
# Total files: 552
#
# Training- 442
#
# validation - 55
#
# Testing - 55
#
#
# ======================================================================
#
# Subdirectory: home repair
# Total files: 280
#
# Training- 224
#
# validation - 28
#
# Testing - 28
#
#
#
# ======================================================================
#
# Subdirectory: horseback riding
# Total files: 524
#
# Training- 420
#
# validation - 52
#
# Testing - 52
#
#
#
# ======================================================================
#
# Subdirectory: hunting
# Total files: 488
#
# Training- 391
#
# validation - 48
#
# Testing - 49
#
#
# ======================================================================
#
# Subdirectory: martial arts
# Total files: 516
#
# Training- 413
#
# validation - 52
#
# Testing - 51
#
#
#
# ======================================================================
#
# Subdirectory: massage therapist
# Total files: 260
#
# Training- 208
#
# validation - 26
#
# Testing - 26
#
#
# ======================================================================
#
# Subdirectory: painting
# Total files: 684
#
# Training- 548
#
# validation - 68
#
# Testing - 68
#
#
#
# ======================================================================
#
# Subdirectory: playing playing basketball
# Total files: 680
#
# Training- 544
#
# validation - 68
#
# Testing - 68
#
#
#
# ======================================================================
#
# Subdirectory: playing tennis
# Total files: 612
#
# Training- 490
#
# validation - 61
#
# Testing - 61
#
#
# ======================================================================
#
# Subdirectory: playing with animals
# Total files: 372
#
# Training- 299
#
# validation - 37
#
# Testing - 36
#
#
#
# ======================================================================
#
# Subdirectory: playing with children
# Total files: 316
#
# Training- 253
#
# validation - 32
#
# Testing - 31
#
#
#
# ======================================================================
#
# Subdirectory: rock climbing
# Total files: 580
#
# Training- 464
#
# validation - 58
#
# Testing - 58
#
#
# ======================================================================
#
# Subdirectory: rollerblading
# Total files: 356
#
# Training- 285
#
# validation - 36
#
# Testing - 35
#
#
#
# ======================================================================
#
# Subdirectory: rope skipping
# Total files: 620
#
# Training- 496
#
# validation - 62
#
# Testing - 62
#
# ======================================================================
#
# Subdirectory: rowing
# Total files: 600
#
# Training- 480
#
# validation - 60
#
# Testing - 60
#
#
#
# ======================================================================
#
# Subdirectory: running
# Total files: 1112
#
# Training- 890
#
# validation - 111
#
# Testing - 111
#
#
# ======================================================================
#
# Subdirectory: sitting
# Total files: 580
#
#
# Training- 464
#
# validation - 58
#
# Testing - 58
#
#
#
# ======================================================================
#
# Subdirectory: skateboarding
# Total files: 736
#
#
# Training- 589
#
# validation - 74
#
# Testing - 73
#
#
#
# ======================================================================
#
# Subdirectory: skiing
# Total files: 1420
#
# Training- 1136
#
# validation - 142
#
# Testing - 142
#
#
#
#
# ======================================================================
#
# Subdirectory: soccer
# Total files: 772
#
# Training- 618
#
# validation - 77
#
# Testing - 77
#
#
#
#
#
# ======================================================================
#
# Subdirectory: softball, general
# Total files: 692
#
# Training- 554
#
# validation - 70
#
# Testing - 68
#
#
#
# ======================================================================
#
# Subdirectory: squash
# Total files: 272
#
#
# Training- 218
#
# validation - 28
#
# Testing - 26
#
#
#
# ======================================================================
#
# Subdirectory: standing
# Total files: 1756
#
# Training- 1405
#
# validation - 176
#
# Testing - 175
#
#
#
# ======================================================================
#
# Subdirectory: swimming
# Total files: 700
#
#
# Training- 560
#
# validation - 70
#
# Testing - 70
#
#
#
# ======================================================================
#
# Subdirectory: tailoring
# Total files: 440
#
# Training- 352
#
# validation - 44
#
# Testing - 44
#
#
#
# ======================================================================
#
# Subdirectory: video exercise workouts
# Total files: 604
#
#
# Training- 484
#
# validation - 61
#
# Testing - 59
#
#
#
# ==========================================================================
#
# Subdirectory: volleyball
# Total files: 368
#
# Training- 295
#
# validation - 37
#
# Testing - 36
#
#
#
#
# ================================================================================
#
# Subdirectory: walking
# Total files: 620
#
#
# Training- 496
#
# validation - 62
#
# Testing - 62
#
#
#
#
# ======================================================================================
#
# Subdirectory: washing and waxing car
# Total files: 328
#
# Training- 263
#
# validation - 33
#
# Testing - 32
#
#
#
# =============================================================================
#
# Subdirectory: windsurfing
# Total files: 272
#
# Training- 218
#
# validation - 28
#
# Testing - 26
#
#
#
# ============================================================================
#
# Subdirectory: yoga
# Total files: 1360
#
#
# Training- 1088
#
# validation - 136
#
# Testing - 136

# %%
import os
import random
import shutil

def move_images(original_directory, duplicate_directory, validation_count):
    # Iterate through each subdirectory in the original directory
    for subdir in os.listdir(original_directory):
        original_subdir_path = os.path.join(original_directory, subdir)
        duplicate_subdir_path = os.path.join(duplicate_directory, subdir)
        
        # Create the corresponding subdirectory in the duplicate directory
        os.makedirs(duplicate_subdir_path, exist_ok=True)
        
        # Get the list of image files in the original subdirectory
        image_files = [file for file in os.listdir(original_subdir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Determine the number of images to move based on the validation count
        num_images_to_move = min(validation_count[subdir], len(image_files))
        
        # Choose a random selection of images to move
        images_to_move = random.sample(image_files, num_images_to_move)
        
        # Move the selected images to the duplicate subdirectory
        for file in images_to_move:
            original_file_path = os.path.join(original_subdir_path, file)
            duplicate_file_path = os.path.join(duplicate_subdir_path, file)
            shutil.move(original_file_path, duplicate_file_path)

    print("Image movement completed successfully.")

# Provide the paths for the original directory and duplicate directory
original_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/VALID/"

# Specify the validation count for each subdirectory
validation_count = {
    "backpacking": 42,
    "bakery": 29,
    "ballet modern jazz": 62,
    "bicycling": 240,
    "calisthenics": 46,
    "carpentry refinishing cabinets": 105,
    "child care": 29,
    "chopping wood": 35,
    "circuit training": 57,
    "cleaning": 45,
    "cook": 27,
    "cooking or food preparation": 82,
    "dancing": 135,
    "eating": 27,
    "farming": 62,
    "fishing": 189,
    "frisbee": 34,
    "gardening": 129,
    "golf": 55,
    "home repair": 28,
    "horseback riding": 52,
    "hunting": 48,
    "martial arts": 52,
    "massage therapist": 26,
    "painting": 68,
    "playing playing basketball": 68,
    "playing tennis": 61,
    "playing with animals": 37,
    "playing with children": 32,
    "rock climbing": 58,
    "rollerblading": 36,
    "rope skipping": 62,
    "rowing": 60,
    "running": 111,
    "sitting": 58,
    "skateboarding": 74,
    "skiing": 142,
    "soccer": 77,
    "softball, general": 70,
    "squash": 28,
    "standing": 176,
    "swimming": 70,
    "tailoring": 44,
    "video exercise workouts": 61,
    "volleyball": 37,
    "walking": 62,
    "washing and waxing car": 33,
    "windsurfing": 28,
    "yoga": 136
}

# Call the function to move the images
move_images(original_directory, duplicate_directory, validation_count)
# Out:
# Image movement completed successfully.

# %%
import os
import random
import shutil

def move_images(original_directory, duplicate_directory, test_count):
    # Iterate through each subdirectory in the original directory
    for subdir in os.listdir(original_directory):
        original_subdir_path = os.path.join(original_directory, subdir)
        duplicate_subdir_path = os.path.join(duplicate_directory, subdir)
        
        # Create the corresponding subdirectory in the duplicate directory
        os.makedirs(duplicate_subdir_path, exist_ok=True)
        
        # Get the list of image files in the original subdirectory
        image_files = [file for file in os.listdir(original_subdir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Determine the number of images to move based on the test count
        num_images_to_move = min(test_count[subdir], len(image_files))
        
        # Choose a random selection of images to move
        images_to_move = random.sample(image_files, num_images_to_move)
        
        # Move the selected images to the duplicate subdirectory
        for file in images_to_move:
            original_file_path = os.path.join(original_subdir_path, file)
            duplicate_file_path = os.path.join(duplicate_subdir_path, file)
            shutil.move(original_file_path, duplicate_file_path)

    print("Image movement completed successfully.")

# Provide the paths for the original directory and duplicate directory
original_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/TEST/"

# Specify the test count for each subdirectory
test_count = {
    "backpacking": 42,
    "bakery": 27,
    "ballet modern jazz": 62,
    "bicycling": 238,
    "calisthenics": 45,
    "carpentry refinishing cabinets": 104,
    "child care": 30,
    "chopping wood": 33,
    "circuit training": 55,
    "cleaning": 43,
    "cook": 25,
    "cooking or food preparation": 82,
    "dancing": 135,
    "eating": 27,
    "farming": 62,
    "fishing": 188,
    "frisbee": 35,
    "gardening": 129,
    "golf": 55,
    "home repair": 28,
    "horseback riding": 52,
    "hunting": 49,
    "martial arts": 51,
    "massage therapist": 26,
    "painting": 68,
    "playing playing basketball": 68,
    "playing tennis": 61,
    "playing with animals": 36,
    "playing with children": 31,
    "rock climbing": 58,
    "rollerblading": 35,
    "rope skipping": 62,
    "rowing": 60,
    "running": 111,
    "sitting": 58,
    "skateboarding": 73,
    "skiing": 142,
    "soccer": 77,
    "softball, general": 68,
    "squash": 26,
    "standing": 175,
    "swimming": 70,
    "tailoring": 44,
    "video exercise workouts": 59,
    "volleyball": 36,
    "walking": 61,
    "washing and waxing car": 33,
    "windsurfing": 27,
    "yoga": 135
}

# Call the function to move the images
move_images(original_directory, duplicate_directory, test_count)
# Out:
# Image movement completed successfully.

# %%
import os
import shutil

def duplicate_directory_structure(source_directory, target_directory):
    # Iterate through all directories and subdirectories in the source directory
    for root, dirs, files in os.walk(source_directory):
        # Get the relative path of the current directory from the source directory
        relative_path = os.path.relpath(root, source_directory)
        
        # Create the corresponding directory in the target directory
        target_subdirectory = os.path.join(target_directory, relative_path)
        os.makedirs(target_subdirectory, exist_ok=True)
        
    print("Directory structure duplicated successfully.")

# Provide the path for the source directory
source_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/TEST/"

# Provide the path for the target directory (where you want to duplicate the structure)
target_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/TEST_GRAY_SCALE/"

# Call the function to duplicate the directory structure
duplicate_directory_structure(source_directory, target_directory)
# Out:
# Directory structure duplicated successfully.

# %%
import shutil

def delete_folder(folder_path):
    # Delete the folder and its contents
    shutil.rmtree(folder_path)

# Specify the path of the folder you want to delete
folder_path = "C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN_GRAY_SCALE/calisthenics/"

# Call the function to delete the folder
delete_folder(folder_path)

# %%
from PIL import Image

def get_image_shape(image_path):
    # Open the image using PIL
    image = Image.open(image_path)

    # Get the shape of the image
    width, height = image.size

    return width, height

# Specify the path of the image file
image_path = "C:/Users/Prasanna P M/Human Project/Project U Turn/TRAIN/volleyball/col_augmented_099037452.jpg"

# Call the function to get the shape of the image
image_width, image_height = get_image_shape(image_path)

print("Image Width:", image_width)
print("Image Height:", image_height)
# Out:
# Image Width: 224
# Image Height: 224

# %%
import os
import cv2
import shutil

def convert_to_grayscale(image_path):
    # Read the image
    image = cv2.imread(image_path)

    # Convert the image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Expand the dimensions to match the shape (224, 224, 1)
    gray_image = gray_image[:, :, None]

    return gray_image

def stack_channels(image_path, gray_image):
    # Read the original image
    original_image = cv2.imread(image_path)

    # Stack the grayscale image channels to create a final image
    final_image = cv2.merge([gray_image, gray_image, gray_image])

    return final_image

def copy_and_convert_images(main_directory, duplicate_directory):
    # Iterate through each subclass directory in the main directory
    for subclass_dir in os.listdir(main_directory):
        subclass_dir_path = os.path.join(main_directory, subclass_dir)
        duplicate_subclass_dir_path = os.path.join(duplicate_directory, subclass_dir)
        
        # Create the corresponding subclass directory in the duplicate directory
        os.makedirs(duplicate_subclass_dir_path, exist_ok=True)
        
        # Get the list of image files in the subclass directory
        image_files = [file for file in os.listdir(subclass_dir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Iterate through each image file
        for file in image_files:
            original_file_path = os.path.join(subclass_dir_path, file)
            duplicate_file_path = os.path.join(duplicate_subclass_dir_path, file)
            
            # Convert the image to grayscale
            gray_image = convert_to_grayscale(original_file_path)
            
            # Stack the grayscale channels to create the final image
            final_image = stack_channels(original_file_path, gray_image)
            
            # Save the final image to the duplicate subclass directory
            cv2.imwrite(duplicate_file_path, final_image)

    print("Image conversion and copying completed successfully.")

# Specify the paths for the main directory and duplicate directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/TEST/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/TEST_GRAY_SCALE/"

# Call the function to copy and convert the images
copy_and_convert_images(main_directory, duplicate_directory)
# Out:
# Image conversion and copying completed successfully.
