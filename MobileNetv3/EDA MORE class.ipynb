# %%
import pandas as pd 
df = pd.read_csv('C:/Users/Prasanna P M/Human Project/Project U Turn/NEW.csv')

# %%
df.head()
# Out:
#    ID           NAME  r ankle_X  r ankle_Y  r knee_X  r knee_Y  r hip_X  \
# 0   1  015601864.jpg        620        394       616       269      573
# 1   2  015599452.jpg         -1         -1        -1        -1      806
# 2   3  005808361.jpg        804        711       816       510      908
# 3   4  086617615.jpg        301        461       305       375      201
# 4   5  060111501.jpg        980        322       896       318      865
#
#    r hip_Y  l hip_X  l hip_Y  ...  r shoulder_Y  l shoulder_X  l shoulder_Y  \
# 0      185      647      188  ...           167           692           185
# 1      543      720      593  ...           281           719           299
# 2      438     1040      454  ...           253          1067           253
# 3      340      294      342  ...           261           314           264
# 4      248      943      226  ...           147           923           123
#
#    l elbow_X  l elbow_Y  l wrist_X  l wrist_Y     Scale  Activity  Category
# 0        693        240        688        313  3.021046   curling    sports
# 1        711        516        545        466  5.641276   curling    sports
# 2       1167        353       1142        478  4.718488   curling    sports
# 3        327        320        362        346  2.681349   curling    sports
# 4        995        163        961        223  3.806403   curling    sports
#
# [5 rows x 37 columns]

# %%
df.shape
# Out:
# (13001, 37)

# %%
activity_counts = df['Activity'].value_counts()

# Get the top 70 activities based on highest occurrence counts
top_activities = activity_counts.head(130)

# Print each activity key and its occurrence count
for activity, count in top_activities.items():
    print(f"{activity}\t \t \t \t {count}")
# Out:
# gardening	 	 	 	 609
# bicycling	 	 	 	 598
# fishing	 	 	 	 528
# carpentry	 	 	 	 393
# skiing	 	 	 	 355
# yoga	 	 	 	 340
# aerobic	 	 	 	 266
# canoeing	 	 	 	 251
# swimming	 	 	 	 235
# cooking or food preparation	 	 	 	 206
# horseback riding	 	 	 	 200
# football	 	 	 	 193
# skateboarding	 	 	 	 184
# painting	 	 	 	 171
# basketball	 	 	 	 170
# running	 	 	 	 167
# ballet, modern, or jazz	 	 	 	 156
# rope skipping	 	 	 	 155
# walking	 	 	 	 154
# tennis	 	 	 	 153
# video exercise workouts, TV conditioning programs	 	 	 	 151
# rock climbing	 	 	 	 145
# sitting	 	 	 	 139
# golf	 	 	 	 138
# horse grooming, feeding, cleaning, harnessing and unharnessing	 	 	 	 123
# dancing	 	 	 	 122
# hunting	 	 	 	 122
# paddleball	 	 	 	 120
# calisthenics	 	 	 	 114
# skating, ice	 	 	 	 113
# tailoring	 	 	 	 110
# backpacking	 	 	 	 105
# playing with animals	 	 	 	 93
# volleyball	 	 	 	 93
# rollerblading	 	 	 	 89
# frisbee	 	 	 	 87
# chopping wood	 	 	 	 86
# therapeutic exercise ball, Fitball exercise	 	 	 	 86
# pilates, general	 	 	 	 85
# cleaning	 	 	 	 84
# badminton	 	 	 	 83
# washing and waxing car	 	 	 	 82
# playing with children	 	 	 	 79
# child care	 	 	 	 74
# bakery, general	 	 	 	 71
# windsurfing	 	 	 	 68
# eating	 	 	 	 68
# squash	 	 	 	 68
# massage therapist	 	 	 	 65
# stretching, mild	 	 	 	 65
# hairstylist (e.g., plaiting hair, manicure, make-up artist)	 	 	 	 64
# fire fighter	 	 	 	 63
# garbage collector, walking, dumping bins into truck	 	 	 	 62
# water walking	 	 	 	 62
# driving tractor	 	 	 	 60
# coaching	 	 	 	 59
# farming, rice, planting, grain milling activities	 	 	 	 59
# moving furniture, household items, carrying boxes	 	 	 	 59
# making bed	 	 	 	 59
# serving food and drinks	 	 	 	 57
# landry	 	 	 	 57
# drums, sitting	 	 	 	 56
# sharpening tools	 	 	 	 56
# touringtravelingvacation involving riding in a vehicle	 	 	 	 56
# fencing	 	 	 	 54
# archery, non-hunting	 	 	 	 53
# farming	 	 	 	 53
# jai alai	 	 	 	 53
# laundry worker	 	 	 	 53
# masonry, concrete	 	 	 	 53
# roofing	 	 	 	 53
# ironing	 	 	 	 52
# truck driving	 	 	 	 51
# kitchen activity	 	 	 	 51
# wash dishes	 	 	 	 51
# guitar, classical, folk, sitting	 	 	 	 50
# vacuuming, general, moderate effort	 	 	 	 50
# bowling	 	 	 	 50
# boxing	 	 	 	 49
# gymnastics	 	 	 	 49
# skydiving, base jumping, bungee jumping	 	 	 	 48
# mopping	 	 	 	 48
# shoveling snow, by hand	 	 	 	 48
# automobile repair	 	 	 	 48
# dog sledding	 	 	 	 47
# hacky sack	 	 	 	 46
# snorkeling 	 	 	 	 45
# slide board exercise, general	 	 	 	 45
# laying or removing carpet	 	 	 	 45
# paddle boarding	 	 	 	 44
# farming, cultivating field	 	 	 	 43
# snow shoeing	 	 	 	 42
# violin, sitting	 	 	 	 42
# surfing	 	 	 	 41
# track and field	 	 	 	 41
# cleaning windows, washing windows, general	 	 	 	 40
# marching band	 	 	 	 40
# shoe repair, general	 	 	 	 38
# guitar rock and roll band	 	 	 	 37
# skating, speed, competitive	 	 	 	 37
# snowmobiling	 	 	 	 37
# broomball	 	 	 	 35
# boxing, punching bag	 	 	 	 35
# lacrosse	 	 	 	 34
# playing chess game	 	 	 	 34
# cricket	 	 	 	 34
# juggling	 	 	 	 34
# farming, feeding cattle, horses	 	 	 	 34
# moto-cross, off-road motor sports, all-terrain vehicle, general	 	 	 	 33
# rugby, touch, non-competitive	 	 	 	 33
# walking the dog	 	 	 	 33
# skiing, water or wakeboarding (Taylor Code 220)	 	 	 	 33
# washing fence, painting fence, moderate effort	 	 	 	 33
# weight lifting, power lifting	 	 	 	 31
# scraping and painting sailboat or powerboat	 	 	 	 31
# food shopping with or without a grocery cart	 	 	 	 31
# accordion	 	 	 	 31
# elder care	 	 	 	 30
# carrying, loading or stacking wood	 	 	 	 30
# cleaning gutters	 	 	 	 30
# yard work, general	 	 	 	 29
# slimnastics, jazzercise	 	 	 	 29
# running, stairs, up	 	 	 	 29
# hiking	 	 	 	 29
# playing table tennis	 	 	 	 29
# coal mining	 	 	 	 28
# climbing hills	 	 	 	 28
# billiards	 	 	 	 27
# cutting and smoking fish, drying fish or meat	 	 	 	 27
# cleaning, sweeping floor or carpet	 	 	 	 27

# %%
df = df[df['Activity'] != 'snorkeling']

# %%
import os

# Activity names
activities = [
    'gardening',
    'bicycling',
    'fishing',
    'carpentry',
    'skiing',
    'yoga',
    'aerobic',
    'canoeing',
    'swimming',
    'cooking or food preparation',
    'horseback riding',
    'football',
    'skateboarding',
    'painting',
    'basketball',
    'running',
    'ballet, modern, or jazz',
    'rope skipping',
    'walking',
    'tennis',
    'video exercise workouts, TV conditioning programs',
    'rock climbing',
    'sitting',
    'golf',
    'horse grooming, feeding, cleaning, harnessing and unharnessing',
    'dancing',
    'hunting',
    'paddleball',
    'calisthenics',
    'skating, ice',
    'tailoring',
    'backpacking',
    'playing with animals',
    'volleyball',
    'rollerblading',
    'frisbee',
    'chopping wood',
    'therapeutic exercise ball, Fitball exercise',
    'pilates, general',
    'cleaning',
    'badminton',
    'washing and waxing car',
    'playing with children',
    'child care',
    'bakery, general',
    'eating',
    'windsurfing',
    'squash',
    'stretching, mild',
    'massage therapist',
    'hairstylist (e.g., plaiting hair, manicure, make-up artist)',
    'fire fighter',
    'water walking',
    'garbage collector, walking, dumping bins into truck',
    'driving tractor',
    'moving furniture, household items, carrying boxes',
    'making bed',
    'coaching',
    'farming, rice, planting, grain milling activities',
    'serving food and drinks',
    'landry',
    'drums, sitting',
    'touringtravelingvacation involving riding in a vehicle',
    'sharpening tools',
    'fencing',
    'roofing',
    'archery, non-hunting',
    'jai alai',
    'masonry, concrete',
    'laundry worker',
    'farming',
    'ironing',
    'truck driving',
    'wash dishes',
    'kitchen activity',
    'bowling',
    'vacuuming, general, moderate effort',
    'guitar, classical, folk, sitting',
    'gymnastics',
    'boxing',
    'shoveling snow, by hand',
    'skydiving, base jumping, bungee jumping',
    'mopping',
    'automobile repair',
    'dog sledding',
    'hacky sack',
    'snorkeling',
    'slide board exercise, general',
    'laying or removing carpet',
    'paddle boarding',
    'farming, cultivating field',
    'violin, sitting',
    'snow shoeing',
    'surfing',
    'track and field',
    'cleaning windows, washing windows, general',
    'marching band',
    'shoe repair, general',
    'snowmobiling',
    'skating, speed, competitive',
    'guitar rock and roll band',
    'boxing, punching bag',
    'broomball',
    'juggling',
    'lacrosse',
    'playing chess game',
    'cricket',
    'farming, feeding cattle, horses',
    'walking the dog',
    'moto-cross, off-road motor sports, all-terrain vehicle, general',
    'rugby, touch, non-competitive',
    'skiing, water or wakeboarding (Taylor Code 220)',
    'washing fence, painting fence, moderate effort',
    'weight lifting, power lifting',
    'scraping and painting sailboat or powerboat',
    'food shopping with or without a grocery cart',
    'accordion',
    'carrying, loading or stacking wood',
    'cleaning gutters',
    'elder care',
    'playing table tennis',
    'hiking',
    'running, stairs, up',
    'yard work, general',
    'slimnastics, jazzercise',
    'coal mining',
    'climbing hills',
    'cleaning, sweeping floor or carpet',
]



# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/"

# Create subfolders based on activity names
for activity in activities:
    subfolder_path = os.path.join(main_directory, activity)
    os.makedirs(subfolder_path, exist_ok=True)

print("Subfolders created successfully!")
# Out:
# Subfolders created successfully!

# %%
# import os
# import shutil
# import pandas as pd

# count = 0
# # Path of the main directory
# main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/"
# data_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data"
# csv_file_path = "C:/Users/Prasanna P M/Human Project/Project U Turn/NEW.csv"  # Replace with the actual path to your CSV file

# # Read the CSV file into a pandas DataFrame
# df = pd.read_csv(csv_file_path)

# # Iterate through each image in the "Data" folder
# for filename in os.listdir(data_directory):
#     image_path = os.path.join(data_directory, filename)
#     if os.path.isfile(image_path):
#         try:
#             # Check if the image filename exists in the "NAME" column of the CSV file
#             matching_rows = df[df["NAME"] == filename]
#             if not matching_rows.empty:
#                 activity_name = matching_rows.iloc[0]["Activity"]

#                 # Check if the activity name is one of the subfolders in the main directory
#                 activity_folder = os.path.join(main_directory, activity_name)
#                 if os.path.isdir(activity_folder):
#                     # Copy the image to the corresponding subfolder
#                     destination_path = os.path.join(activity_folder, filename)
#                     shutil.copy(image_path, destination_path)
# #                     print(f"Image {filename} copied to {activity_folder}")
# #                 else:
# #                     print(f"Activity folder {activity_folder} does not exist.")
#         except FileNotFoundError:
#             print(f"File {image_path} not found.")
#             count = count + 1
#     else:
#         print(f"File {image_path} is not a regular file.")

# print("Image copying completed!")
# print(count)
# Out:
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\001302528.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\001779489.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\002262156.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\003428514.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\004486746.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\004552550.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\006267213.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\007091331.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\010140815.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\013295227.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\013971019.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\016164034.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\020594864.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\024607414.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\031427010.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\033341800.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\033964532.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\036195407.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\041993384.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\042367641.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\048208320.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\049603481.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\049743665.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\056139037.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\056195414.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\057495489.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\058200928.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\058996065.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\059619645.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\060940792.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\061041120.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\064069127.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\066388984.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\067279071.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\068062393.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\071210893.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\074949551.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\077636746.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\078292165.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\078789631.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\079396773.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\090641513.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\091845167.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\094238136.jpg not found.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\096473756.jpg not found.
# Image copying completed!
# 45

# %%
import os
import shutil
import pandas as pd

count = 0
# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/"
data_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data"
csv_file_path = "C:/Users/Prasanna P M/Human Project/Project U Turn/NEW.csv"  # Replace with the actual path to your CSV file

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(csv_file_path)

# Iterate through each image in the "Data" folder
for filename in os.listdir(data_directory):
    image_path = os.path.join(data_directory, filename)
    if os.path.isfile(image_path):
        try:
            # Check if the image filename exists in the "NAME" column of the CSV file
            matching_rows = df[df["NAME"] == filename]
            if not matching_rows.empty:
                activity_name = matching_rows.iloc[0]["Activity"]

                # Check if the activity name is one of the subfolders in the main directory
                activity_folder = os.path.join(main_directory, activity_name)
                if os.path.isdir(activity_folder):
                    # Copy the image to the corresponding subfolder
                    destination_path = os.path.join(activity_folder, filename)
                    shutil.copy(image_path, destination_path)
                    print(f"Image {filename} copied to {activity_folder}")
                else:
                    print(f"Activity folder {activity_folder} does not exist.")
            else:
                print(f"No matching rows found in the CSV for {filename}.")
        except FileNotFoundError:
            print(f"File {image_path} not found.")
            count += 1
    else:
        print(f"File {image_path} is not a regular file.")

print("Image copying completed!")
print(count)
# Out:
# No matching rows found in the CSV for 000001163.jpg.
# Image 000003072.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/rope skipping
# Image 000004812.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/stretching, mild
# No matching rows found in the CSV for 000005283.jpg.
# Image 000013469.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/wash dishes
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/hang gliding does not exist.
# Image 000022704.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/archery, non-hunting
# No matching rows found in the CSV for 000024087.jpg.
# No matching rows found in the CSV for 000024100.jpg.
# No matching rows found in the CSV for 000024293.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/shuffleboard does not exist.
# Image 000030708.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/stretching, mild
# No matching rows found in the CSV for 000030973.jpg.
# No matching rows found in the CSV for 000033016.jpg.
# Image 000040154.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# Image 000041029.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cooking or food preparation
# No matching rows found in the CSV for 000050999.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/rodeo sports does not exist.
# Image 000059794.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/jai alai
# No matching rows found in the CSV for 000061164.jpg.
# Image 000065339.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/chopping wood
# No matching rows found in the CSV for 000071686.jpg.
# No matching rows found in the CSV for 000078951.jpg.
# Image 000085370.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/sitting
# No matching rows found in the CSV for 000090584.jpg.
# No matching rows found in the CSV for 000094304.jpg.
# No matching rows found in the CSV for 000094342.jpg.
# No matching rows found in the CSV for 000099186.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/pistol shooting does not exist.
# Image 000109154.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/carpentry
# Image 000111209.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/rope skipping
# Image 000114595.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cleaning windows, washing windows, general
# No matching rows found in the CSV for 000120361.jpg.
# No matching rows found in the CSV for 000124344.jpg.
# No matching rows found in the CSV for 000128443.jpg.
# No matching rows found in the CSV for 000131987.jpg.
# No matching rows found in the CSV for 000133364.jpg.
# Image 000135363.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/serving food and drinks
# No matching rows found in the CSV for 000141822.jpg.
# No matching rows found in the CSV for 000142573.jpg.
# Image 000142834.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# Image 000144722.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/shoe repair, general
# No matching rows found in the CSV for 000147382.jpg.
# Image 000156511.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/dancing
# Image 000165249.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/basketball
# Image 000170503.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/food shopping with or without a grocery cart
# No matching rows found in the CSV for 000172482.jpg.
# No matching rows found in the CSV for 000187274.jpg.
# No matching rows found in the CSV for 000199214.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/trampoline, competitive does not exist.
# No matching rows found in the CSV for 000208151.jpg.
# Image 000214092.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/paddleball
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/woodwind does not exist.
# Image 000245459.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/painting
# Image 000249545.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/guitar, classical, folk, sitting
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cutting and smoking fish, drying fish or meat does not exist.
# Image 000252755.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bakery, general
# No matching rows found in the CSV for 000263216.jpg.
# No matching rows found in the CSV for 000267099.jpg.
# No matching rows found in the CSV for 000272874.jpg.
# Image 000275100.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/volleyball
# Image 000298013.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/rope skipping
# Image 000302087.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cooking or food preparation
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/pushing a wheelchair, non-occupational does not exist.
# Image 000316731.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/violin, sitting
# No matching rows found in the CSV for 000321826.jpg.
# No matching rows found in the CSV for 000324793.jpg.
# Image 000336238.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/washing and waxing car
# Image 000337885.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/snow shoeing
# No matching rows found in the CSV for 000338399.jpg.
# Image 000338785.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/driving tractor
# Image 000346846.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bicycling
# Image 000350466.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bicycling
# No matching rows found in the CSV for 000351085.jpg.
# Image 000354899.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cleaning windows, washing windows, general
# Image 000360424.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/golf
# Image 000361586.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# No matching rows found in the CSV for 000364670.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/felling trees does not exist.
# Image 000371966.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# Image 000374509.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/washing and waxing car
# Image 000377819.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/squash
# Image 000381992.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/wash dishes
# No matching rows found in the CSV for 000383029.jpg.
# Image 000391837.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/masonry, concrete
# No matching rows found in the CSV for 000392606.jpg.
# No matching rows found in the CSV for 000392932.jpg.
# Image 000402528.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/snow shoeing
# Image 000406059.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skating, ice
# No matching rows found in the CSV for 000410145.jpg.
# No matching rows found in the CSV for 000412715.jpg.
# No matching rows found in the CSV for 000418744.jpg.
# Image 000419716.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skating, ice
# No matching rows found in the CSV for 000428176.jpg.
# Image 000435958.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/dancing
# Image 000436327.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cleaning
# Image 000437064.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/automobile repair
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/card playing,sitting does not exist.
# Image 000437398.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/tailoring
# No matching rows found in the CSV for 000440161.jpg.
# No matching rows found in the CSV for 000448169.jpg.
# Image 000460055.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/slide board exercise, general
# Image 000460994.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/horse grooming, feeding, cleaning, harnessing and unharnessing
# Image 000463202.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/swimming
# Image 000464448.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/boxing
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/pulling rickshaw does not exist.
# No matching rows found in the CSV for 000493998.jpg.
# No matching rows found in the CSV for 000502550.jpg.
# Image 000506158.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/ironing
# No matching rows found in the CSV for 000506711.jpg.
# No matching rows found in the CSV for 000521252.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/piano does not exist.
# Image 000531348.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bicycling
# No matching rows found in the CSV for 000532419.jpg.
# No matching rows found in the CSV for 000533914.jpg.
# Image 000534899.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/canoeing
# Image 000550580.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/dancing
# Image 000552212.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# Image 000559416.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cleaning
# No matching rows found in the CSV for 000563131.jpg.
# No matching rows found in the CSV for 000563328.jpg.
# Image 000565210.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# Image 000568822.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/rock climbing
# No matching rows found in the CSV for 000572093.jpg.
# No matching rows found in the CSV for 000575326.jpg.
# No matching rows found in the CSV for 000575866.jpg.
# Image 000577066.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# No matching rows found in the CSV for 000580377.jpg.
# No matching rows found in the CSV for 000584160.jpg.
# Image 000586473.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/aerobic
# Image 000593350.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/farming, rice, planting, grain milling activities
# Image 000594176.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/landry
# No matching rows found in the CSV for 000602204.jpg.
# No matching rows found in the CSV for 000604704.jpg.
# No matching rows found in the CSV for 000607062.jpg.
# Image 000608753.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/farming, cultivating field
# Image 000612865.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/basketball
# Image 000618382.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/moving furniture, household items, carrying boxes
# Image 000628555.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/rollerblading
# Image 000637904.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/running
# Image 000638587.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/therapeutic exercise ball, Fitball exercise
# No matching rows found in the CSV for 000644944.jpg.
# Image 000646436.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# No matching rows found in the CSV for 000648808.jpg.
# Image 000648952.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# Image 000651632.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/hunting
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/maple syrupingsugar bushing (including carrying buckets, carrying wood) does not exist.
# No matching rows found in the CSV for 000687796.jpg.
# No matching rows found in the CSV for 000692010.jpg.
# Image 000695213.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/horse grooming, feeding, cleaning, harnessing and unharnessing
# No matching rows found in the CSV for 000695759.jpg.
# No matching rows found in the CSV for 000698226.jpg.
# Image 000699079.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/yoga
# No matching rows found in the CSV for 000708647.jpg.
# No matching rows found in the CSV for 000709181.jpg.
# No matching rows found in the CSV for 000709653.jpg.
# Image 000713002.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/painting
# Image 000719296.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/canoeing
# Image 000721995.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/paddleball
# Image 000725243.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# Image 000731049.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cleaning windows, washing windows, general
# No matching rows found in the CSV for 000735304.jpg.
# No matching rows found in the CSV for 000735783.jpg.
# Image 000742031.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/swimming
# No matching rows found in the CSV for 000746314.jpg.
# Image 000754109.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/drums, sitting
# Image 000756287.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/juggling
# No matching rows found in the CSV for 000759142.jpg.
# Image 000766403.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/dancing
# Image 000769780.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bicycling
# Image 000773027.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/chopping wood
# No matching rows found in the CSV for 000775965.jpg.
# Image 000784159.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/serving food and drinks
# Image 000784492.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/masonry, concrete
# No matching rows found in the CSV for 000795418.jpg.
# No matching rows found in the CSV for 000805262.jpg.
# Image 000810094.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skiing
# Image 000810820.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/accordion
# No matching rows found in the CSV for 000811881.jpg.
# No matching rows found in the CSV for 000822313.jpg.
# No matching rows found in the CSV for 000823624.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/airline flight attendant does not exist.
# Image 000831994.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/farming, driving tasks (e.g., driving tractor or harvester) does not exist.
# Image 000835470.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/playing with animals
# No matching rows found in the CSV for 000836368.jpg.
# Image 000845150.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/ballet, modern, or jazz
# Image 000846442.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/moto-cross, off-road motor sports, all-terrain vehicle, general
# Image 000848601.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/carpentry
# Image 000849558.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/aerobic
# No matching rows found in the CSV for 000855477.jpg.
# No matching rows found in the CSV for 000861900.jpg.
# No matching rows found in the CSV for 000868121.jpg.
# No matching rows found in the CSV for 000877476.jpg.
# Image 000881483.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/walking
# No matching rows found in the CSV for 000886329.jpg.
# Image 000899429.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bicycling
# No matching rows found in the CSV for 000900566.jpg.
# No matching rows found in the CSV for 000903847.jpg.
# Image 000905416.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# Image 000906310.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/yoga
# No matching rows found in the CSV for 000908703.jpg.
# Image 000909418.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/aerobic
# Image 000909818.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/aerobic
# Image 000916555.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/snowmobiling
# No matching rows found in the CSV for 000919705.jpg.
# No matching rows found in the CSV for 000920090.jpg.
# No matching rows found in the CSV for 000920567.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/trampoline, competitive does not exist.
# No matching rows found in the CSV for 000924159.jpg.
# Image 000924231.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/running
# Image 000925252.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/track and field
# No matching rows found in the CSV for 000925392.jpg.
# No matching rows found in the CSV for 000931029.jpg.
# Image 000933162.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/walking
# No matching rows found in the CSV for 000934495.jpg.
# No matching rows found in the CSV for 000947513.jpg.
# Image 000950620.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/tennis
# No matching rows found in the CSV for 000953895.jpg.
# Image 000955819.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/squash
# Image 000956171.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/sitting
# Image 000958269.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fire fighter
# No matching rows found in the CSV for 000958564.jpg.
# Image 000966627.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/football
# No matching rows found in the CSV for 000967254.jpg.
# No matching rows found in the CSV for 000970035.jpg.
# No matching rows found in the CSV for 000972588.jpg.
# Image 000973096.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/sitting
# Image 000977085.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/basketball
# Image 000977223.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/touringtravelingvacation involving riding in a vehicle
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/high ropes course, multiple elements does not exist.
# No matching rows found in the CSV for 000982755.jpg.
# No matching rows found in the CSV for 000987961.jpg.
# Image 000988787.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/yoga
# Image 000991070.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/jai alai
# Image 000992321.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/kitchen activity
# No matching rows found in the CSV for 000992382.jpg.
# No matching rows found in the CSV for 000995363.jpg.
# No matching rows found in the CSV for 000995974.jpg.
# No matching rows found in the CSV for 000996923.jpg.
# Image 000997878.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/yoga
# No matching rows found in the CSV for 000999377.jpg.
# Image 001004698.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/roofing
# Image 001009041.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/basketball
# No matching rows found in the CSV for 001013118.jpg.
# No matching rows found in the CSV for 001017500.jpg.
# No matching rows found in the CSV for 001020419.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/farming, driving tasks (e.g., driving tractor or harvester) does not exist.
# Image 001028450.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/frisbee
# Image 001030340.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/ballet, modern, or jazz
# No matching rows found in the CSV for 001051322.jpg.
# Image 001056712.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/coal mining
# Image 001060742.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/snow shoeing
# Image 001067013.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bowling
# No matching rows found in the CSV for 001071530.jpg.
# Image 001072280.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/weight lifting, power lifting
# No matching rows found in the CSV for 001073898.jpg.
# No matching rows found in the CSV for 001081108.jpg.
# Image 001083765.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/video exercise workouts, TV conditioning programs
# No matching rows found in the CSV for 001089547.jpg.
# No matching rows found in the CSV for 001090700.jpg.
# Image 001096365.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/tailoring
# Image 001096592.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bicycling
# Image 001099583.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/farming
# No matching rows found in the CSV for 001102808.jpg.
# No matching rows found in the CSV for 001103126.jpg.
# No matching rows found in the CSV for 001105440.jpg.
# Image 001111678.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/badminton
# No matching rows found in the CSV for 001115459.jpg.
# Image 001119931.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/yard work, general
# No matching rows found in the CSV for 001123898.jpg.
# Image 001126945.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/weight lifting, power lifting
# Image 001130254.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/tennis
# No matching rows found in the CSV for 001135364.jpg.
# Image 001137337.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/basketball
# Image 001138967.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skiing
# Image 001141798.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/tailoring
# Image 001143268.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/football
# Image 001152601.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# Image 001155628.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/boxing
# Image 001162054.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/rock climbing
# Image 001162660.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/running
# Image 001164490.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skiing
# Image 001170263.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/windsurfing
# No matching rows found in the CSV for 001170661.jpg.
# No matching rows found in the CSV for 001176509.jpg.
# No matching rows found in the CSV for 001177988.jpg.
# Image 001187135.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/accordion
# Image 001197869.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skating, ice
# Image 001200303.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/running
# No matching rows found in the CSV for 001200916.jpg.
# No matching rows found in the CSV for 001206994.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/trampoline, competitive does not exist.
# No matching rows found in the CSV for 001210312.jpg.
# Image 001210848.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/carpentry
# Image 001211527.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/sharpening tools
# No matching rows found in the CSV for 001212077.jpg.
# No matching rows found in the CSV for 001213746.jpg.
# No matching rows found in the CSV for 001215447.jpg.
# Image 001215677.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/tailoring
# Image 001216835.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skateboarding
# No matching rows found in the CSV for 001217984.jpg.
# No matching rows found in the CSV for 001218755.jpg.
# Image 001229066.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skateboarding
# No matching rows found in the CSV for 001240404.jpg.
# Image 001241609.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/ballet, modern, or jazz
# Image 001259261.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# Image 001260752.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/video exercise workouts, TV conditioning programs
# No matching rows found in the CSV for 001264260.jpg.
# No matching rows found in the CSV for 001265783.jpg.
# Image 001272728.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/walking the dog
# Image 001275648.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/dancing
# Image 001276543.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/swimming
# Image 001282165.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# Image 001289747.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/rope skipping
# No matching rows found in the CSV for 001293689.jpg.
# Image 001300192.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skiing
# No matching rows found in the CSV for 001301021.jpg.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\001302528.jpg not found.
# No matching rows found in the CSV for 001309446.jpg.
# Image 001312213.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skateboarding
# No matching rows found in the CSV for 001313337.jpg.
# Image 001316277.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skateboarding
# No matching rows found in the CSV for 001322881.jpg.
# No matching rows found in the CSV for 001328120.jpg.
# Image 001340481.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/snow shoeing
# No matching rows found in the CSV for 001344404.jpg.
# No matching rows found in the CSV for 001360440.jpg.
# Image 001361415.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/dog sledding
# Image 001363985.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/ballet, modern, or jazz
# No matching rows found in the CSV for 001365784.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fire fighter, hauling hoses on ground, carryinghoisting equipment, breaking down walls etc., wearin does not exist.
# Image 001367765.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/water walking
# No matching rows found in the CSV for 001368241.jpg.
# No matching rows found in the CSV for 001374383.jpg.
# No matching rows found in the CSV for 001374555.jpg.
# No matching rows found in the CSV for 001376469.jpg.
# No matching rows found in the CSV for 001386214.jpg.
# Image 001394902.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# No matching rows found in the CSV for 001398079.jpg.
# No matching rows found in the CSV for 001398171.jpg.
# Image 001399341.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/painting
# No matching rows found in the CSV for 001401452.jpg.
# No matching rows found in the CSV for 001407966.jpg.
# Image 001419663.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/moving furniture, household items, carrying boxes
# No matching rows found in the CSV for 001430749.jpg.
# No matching rows found in the CSV for 001431528.jpg.
# No matching rows found in the CSV for 001436736.jpg.
# Image 001437021.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/basketball
# No matching rows found in the CSV for 001438145.jpg.
# Image 001439349.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/swimming
# No matching rows found in the CSV for 001444210.jpg.
# No matching rows found in the CSV for 001447064.jpg.
# Image 001454467.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/elder care
# No matching rows found in the CSV for 001462854.jpg.
# No matching rows found in the CSV for 001469339.jpg.
# No matching rows found in the CSV for 001480342.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/hang gliding does not exist.
# No matching rows found in the CSV for 001485612.jpg.
# No matching rows found in the CSV for 001491026.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/laughing does not exist.
# No matching rows found in the CSV for 001496120.jpg.
# Image 001499850.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skiing
# No matching rows found in the CSV for 001510745.jpg.
# Image 001511068.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# No matching rows found in the CSV for 001517298.jpg.
# Image 001521653.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/carpentry
# Image 001522247.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# Image 001526484.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cooking or food preparation
# Image 001527384.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/basketball
# No matching rows found in the CSV for 001536625.jpg.
# No matching rows found in the CSV for 001537562.jpg.
# Image 001539489.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# Image 001541496.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/sitting
# Image 001541517.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/farming, cultivating field
# No matching rows found in the CSV for 001545662.jpg.
# Image 001548246.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/painting
# No matching rows found in the CSV for 001549992.jpg.
# No matching rows found in the CSV for 001558758.jpg.
# No matching rows found in the CSV for 001564330.jpg.
# No matching rows found in the CSV for 001564732.jpg.
# No matching rows found in the CSV for 001574061.jpg.
# Image 001583807.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bowling
# Image 001594569.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bicycling
# No matching rows found in the CSV for 001602816.jpg.
# Image 001603640.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/tennis
# No matching rows found in the CSV for 001605882.jpg.
# Image 001612465.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cleaning gutters
# Image 001616954.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/archery, non-hunting
# No matching rows found in the CSV for 001618467.jpg.
# No matching rows found in the CSV for 001620040.jpg.
# Image 001624344.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/rope skipping
# No matching rows found in the CSV for 001630590.jpg.
# No matching rows found in the CSV for 001643606.jpg.
# No matching rows found in the CSV for 001652273.jpg.
# No matching rows found in the CSV for 001653712.jpg.
# No matching rows found in the CSV for 001653945.jpg.
# No matching rows found in the CSV for 001658783.jpg.
# No matching rows found in the CSV for 001659248.jpg.
# Image 001661623.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/sharpening tools
# Image 001667155.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/ballet, modern, or jazz
# No matching rows found in the CSV for 001671109.jpg.
# Image 001683332.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/tennis
# Image 001686287.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# Image 001686718.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/carpentry
# No matching rows found in the CSV for 001689336.jpg.
# No matching rows found in the CSV for 001691280.jpg.
# No matching rows found in the CSV for 001692935.jpg.
# No matching rows found in the CSV for 001693075.jpg.
# No matching rows found in the CSV for 001694766.jpg.
# No matching rows found in the CSV for 001696913.jpg.
# Image 001703146.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/carpentry
# No matching rows found in the CSV for 001712209.jpg.
# Image 001717299.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/basketball
# Image 001729398.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/swimming
# No matching rows found in the CSV for 001730012.jpg.
# No matching rows found in the CSV for 001734593.jpg.
# Image 001738874.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/carpentry
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/high ropes course, multiple elements does not exist.
# No matching rows found in the CSV for 001749821.jpg.
# No matching rows found in the CSV for 001755236.jpg.
# Image 001755272.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/making bed
# No matching rows found in the CSV for 001756546.jpg.
# No matching rows found in the CSV for 001758992.jpg.
# No matching rows found in the CSV for 001760252.jpg.
# Image 001761651.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/canoeing
# Image 001763141.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/laundry worker
# Image 001763483.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cooking or food preparation
# No matching rows found in the CSV for 001770445.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/driving automobile or light truck does not exist.
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\001779489.jpg not found.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/plumbing activities does not exist.
# No matching rows found in the CSV for 001787848.jpg.
# Image 001795786.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# No matching rows found in the CSV for 001800656.jpg.
# No matching rows found in the CSV for 001802901.jpg.
# Image 001803201.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cooking or food preparation
# Image 001808109.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/therapeutic exercise ball, Fitball exercise
# No matching rows found in the CSV for 001810944.jpg.
# Image 001811018.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/truck driving
# Image 001812404.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/yoga
# Image 001815797.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/yoga
# Image 001821403.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/driving tractor
# No matching rows found in the CSV for 001822183.jpg.
# Image 001823258.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/juggling
# Image 001832617.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/horseback riding
# Image 001834866.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bicycling
# No matching rows found in the CSV for 001834988.jpg.
# No matching rows found in the CSV for 001835572.jpg.
# Image 001835838.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/snowmobiling
# Image 001839068.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skiing
# No matching rows found in the CSV for 001843421.jpg.
# No matching rows found in the CSV for 001845642.jpg.
# Image 001846590.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/horseback riding
# Image 001852458.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/running, stairs, up
# Image 001855554.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/aerobic
# Image 001857072.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/aerobic
# Image 001858033.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/washing and waxing car
# Image 001859206.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bicycling
# Image 001872471.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cooking or food preparation
# No matching rows found in the CSV for 001873029.jpg.
# No matching rows found in the CSV for 001888088.jpg.
# No matching rows found in the CSV for 001900740.jpg.
# No matching rows found in the CSV for 001903225.jpg.
# No matching rows found in the CSV for 001904341.jpg.
# Image 001911609.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/canoeing
# No matching rows found in the CSV for 001912635.jpg.
# No matching rows found in the CSV for 001912897.jpg.
# No matching rows found in the CSV for 001914487.jpg.
# Image 001915549.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/boxing, punching bag
# No matching rows found in the CSV for 001917291.jpg.
# No matching rows found in the CSV for 001919228.jpg.
# Image 001921053.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/making bed
# Image 001923170.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# No matching rows found in the CSV for 001929913.jpg.
# No matching rows found in the CSV for 001930442.jpg.
# No matching rows found in the CSV for 001932763.jpg.
# Image 001940125.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/running
# No matching rows found in the CSV for 001941556.jpg.
# No matching rows found in the CSV for 001943267.jpg.
# No matching rows found in the CSV for 001952928.jpg.
# No matching rows found in the CSV for 001961053.jpg.
# Image 001965148.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/laying or removing carpet
# No matching rows found in the CSV for 001968322.jpg.
# Image 001971054.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skiing
# Image 001971973.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/yoga
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/laughing does not exist.
# No matching rows found in the CSV for 001990148.jpg.
# Image 001993217.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/yoga
# No matching rows found in the CSV for 001997293.jpg.
# No matching rows found in the CSV for 002000516.jpg.
# No matching rows found in the CSV for 002001172.jpg.
# No matching rows found in the CSV for 002006710.jpg.
# No matching rows found in the CSV for 002007120.jpg.
# No matching rows found in the CSV for 002012172.jpg.
# No matching rows found in the CSV for 002013785.jpg.
# No matching rows found in the CSV for 002016138.jpg.
# Image 002019492.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# Image 002021752.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/yoga
# Image 002023623.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/scraping and painting sailboat or powerboat
# Image 002024938.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/football
# Image 002027021.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/canoeing
# No matching rows found in the CSV for 002027997.jpg.
# Image 002034083.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/automobile repair
# No matching rows found in the CSV for 002034108.jpg.
# No matching rows found in the CSV for 002040161.jpg.
# Image 002047846.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/kitchen activity
# Image 002051092.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/guitar rock and roll band
# No matching rows found in the CSV for 002052251.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/curling does not exist.
# Image 002062663.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/badminton
# No matching rows found in the CSV for 002066185.jpg.
# Image 002076409.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/washing and waxing car
# Image 002076789.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/farming, rice, planting, grain milling activities
# No matching rows found in the CSV for 002083683.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/hang gliding does not exist.
# Image 002086147.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/basketball
# No matching rows found in the CSV for 002090951.jpg.
# Image 002093412.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/rock climbing
# Image 002094496.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/carpentry
# No matching rows found in the CSV for 002095217.jpg.
# No matching rows found in the CSV for 002097999.jpg.
# Image 002098300.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/aerobic
# Image 002098498.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# No matching rows found in the CSV for 002100916.jpg.
# No matching rows found in the CSV for 002102481.jpg.
# Image 002103690.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/roofing
# No matching rows found in the CSV for 002108066.jpg.
# Image 002114982.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# No matching rows found in the CSV for 002116381.jpg.
# No matching rows found in the CSV for 002126941.jpg.
# Image 002138885.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/squash
# No matching rows found in the CSV for 002143987.jpg.
# Image 002158991.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bicycling
# Image 002162699.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/running, stairs, up
# Image 002163932.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/ballet, modern, or jazz
# No matching rows found in the CSV for 002164069.jpg.
# No matching rows found in the CSV for 002164179.jpg.
# Image 002178895.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/drums, sitting
# Image 002180679.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/walking
# Image 002182340.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/yoga
# Image 002183188.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/basketball
# No matching rows found in the CSV for 002184671.jpg.
# Image 002185138.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/paddle boarding
# Image 002191333.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/rope skipping
# No matching rows found in the CSV for 002192643.jpg.
# No matching rows found in the CSV for 002194147.jpg.
# Image 002198181.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/yard work, general
# Image 002198652.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# No matching rows found in the CSV for 002201612.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/wrestling (one match = 5 minutes) does not exist.
# Image 002209375.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/sharpening tools
# Image 002212355.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/therapeutic exercise ball, Fitball exercise
# Image 002213328.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/frisbee
# No matching rows found in the CSV for 002213445.jpg.
# Image 002213916.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/masonry, concrete
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/farming, driving tasks (e.g., driving tractor or harvester) does not exist.
# No matching rows found in the CSV for 002220281.jpg.
# No matching rows found in the CSV for 002222064.jpg.
# Image 002225013.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/rope skipping
# Image 002225035.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# Image 002230170.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/yoga
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/billiards does not exist.
# Image 002234493.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/pilates, general
# Image 002234679.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/weight lifting, power lifting
# No matching rows found in the CSV for 002242589.jpg.
# Image 002246931.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skiing
# Image 002250433.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cooking or food preparation
# No matching rows found in the CSV for 002256165.jpg.
# No matching rows found in the CSV for 002256451.jpg.
# Image 002256858.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/swimming
# Image 002256970.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/track and field
# File C:/Users/Prasanna P M/Human Project/Project U Turn/Data/Data\002262156.jpg not found.
# Image 002268684.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/chopping wood
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cutting and smoking fish, drying fish or meat does not exist.
# Image 002282073.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/horseback riding
# No matching rows found in the CSV for 002292157.jpg.
# No matching rows found in the CSV for 002294843.jpg.
# Image 002304709.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/paddleball
# No matching rows found in the CSV for 002305278.jpg.
# No matching rows found in the CSV for 002306339.jpg.
# Image 002308548.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/painting
# Image 002308962.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/canoeing
# ...
# No matching rows found in the CSV for 099213564.jpg.
# Image 099215144.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fire fighter
# No matching rows found in the CSV for 099215801.jpg.
# Image 099217171.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/carpentry
# No matching rows found in the CSV for 099248350.jpg.
# No matching rows found in the CSV for 099251462.jpg.
# No matching rows found in the CSV for 099253807.jpg.
# No matching rows found in the CSV for 099258180.jpg.
# Image 099258988.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/driving tractor
# Image 099265475.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/horseback riding
# Image 099272462.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/landry
# No matching rows found in the CSV for 099273730.jpg.
# Image 099278702.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# Image 099280398.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/football
# Image 099281446.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/water walking
# No matching rows found in the CSV for 099281684.jpg.
# Image 099283213.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# Image 099285878.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/painting
# Image 099290349.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/running
# No matching rows found in the CSV for 099296480.jpg.
# No matching rows found in the CSV for 099296500.jpg.
# Image 099300804.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/snowmobiling
# No matching rows found in the CSV for 099316374.jpg.
# Image 099317079.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# No matching rows found in the CSV for 099325502.jpg.
# No matching rows found in the CSV for 099330719.jpg.
# No matching rows found in the CSV for 099336086.jpg.
# No matching rows found in the CSV for 099336750.jpg.
# Image 099337279.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/washing and waxing car
# Image 099338988.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/ballet, modern, or jazz
# No matching rows found in the CSV for 099341671.jpg.
# Image 099347993.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bicycling
# No matching rows found in the CSV for 099348352.jpg.
# No matching rows found in the CSV for 099350156.jpg.
# No matching rows found in the CSV for 099356500.jpg.
# Image 099359737.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/lacrosse
# Image 099363014.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/basketball
# No matching rows found in the CSV for 099369803.jpg.
# No matching rows found in the CSV for 099377310.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/reading does not exist.
# Image 099391199.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bicycling
# No matching rows found in the CSV for 099399773.jpg.
# No matching rows found in the CSV for 099405596.jpg.
# No matching rows found in the CSV for 099406198.jpg.
# Image 099407214.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/basketball
# No matching rows found in the CSV for 099413936.jpg.
# Image 099417379.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/sitting
# Image 099428799.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cooking or food preparation
# Image 099433030.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/archery, non-hunting
# No matching rows found in the CSV for 099436898.jpg.
# Image 099443018.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/badminton
# No matching rows found in the CSV for 099450510.jpg.
# Image 099456426.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# No matching rows found in the CSV for 099456557.jpg.
# Image 099465422.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/laundry worker
# Image 099469013.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/massage therapist
# Image 099475369.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/farming
# Image 099481303.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# No matching rows found in the CSV for 099481929.jpg.
# Image 099484981.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cooking or food preparation
# No matching rows found in the CSV for 099486632.jpg.
# Image 099490782.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# No matching rows found in the CSV for 099494999.jpg.
# No matching rows found in the CSV for 099503123.jpg.
# No matching rows found in the CSV for 099505175.jpg.
# No matching rows found in the CSV for 099505275.jpg.
# No matching rows found in the CSV for 099515941.jpg.
# No matching rows found in the CSV for 099518212.jpg.
# No matching rows found in the CSV for 099542151.jpg.
# No matching rows found in the CSV for 099543752.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/reading does not exist.
# No matching rows found in the CSV for 099551645.jpg.
# Image 099552023.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/water walking
# No matching rows found in the CSV for 099554926.jpg.
# No matching rows found in the CSV for 099556890.jpg.
# Image 099560420.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cooking or food preparation
# Image 099560871.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bakery, general
# No matching rows found in the CSV for 099563111.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/unicycling does not exist.
# Image 099573445.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/archery, non-hunting
# No matching rows found in the CSV for 099574823.jpg.
# Image 099580237.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/kitchen activity
# No matching rows found in the CSV for 099585643.jpg.
# No matching rows found in the CSV for 099588628.jpg.
# Image 099590664.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/marching band
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/pulling rickshaw does not exist.
# No matching rows found in the CSV for 099601278.jpg.
# Image 099606696.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/laundry worker
# No matching rows found in the CSV for 099607692.jpg.
# No matching rows found in the CSV for 099611517.jpg.
# Image 099614524.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/walking the dog
# Image 099614683.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bicycling
# No matching rows found in the CSV for 099615079.jpg.
# Image 099615290.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/slide board exercise, general
# No matching rows found in the CSV for 099615767.jpg.
# Image 099616030.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/moto-cross, off-road motor sports, all-terrain vehicle, general
# No matching rows found in the CSV for 099622449.jpg.
# Image 099624210.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/football
# Image 099633392.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bicycling
# No matching rows found in the CSV for 099633434.jpg.
# Image 099648887.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/playing table tennis
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/shuffleboard does not exist.
# No matching rows found in the CSV for 099652631.jpg.
# Image 099655411.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/sharpening tools
# No matching rows found in the CSV for 099655674.jpg.
# Image 099656142.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fire fighter
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/pistol shooting does not exist.
# No matching rows found in the CSV for 099663684.jpg.
# Image 099668328.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/canoeing
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/moving, carrying or pushing heavy objects, 75 lbs or more, only active time (e.g., desks, moving van does not exist.
# No matching rows found in the CSV for 099672640.jpg.
# Image 099672821.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/canoeing
# No matching rows found in the CSV for 099673377.jpg.
# No matching rows found in the CSV for 099676258.jpg.
# Image 099681094.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/basketball
# No matching rows found in the CSV for 099682145.jpg.
# No matching rows found in the CSV for 099683476.jpg.
# Image 099684928.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/roofing
# No matching rows found in the CSV for 099687425.jpg.
# Image 099691089.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/rugby, touch, non-competitive
# Image 099694942.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/backpacking
# Image 099698690.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/laundry worker
# Image 099699050.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cleaning
# Image 099707488.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/dog sledding
# No matching rows found in the CSV for 099709202.jpg.
# No matching rows found in the CSV for 099711363.jpg.
# Image 099712450.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/therapeutic exercise ball, Fitball exercise
# No matching rows found in the CSV for 099714944.jpg.
# Image 099716281.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skating, ice
# No matching rows found in the CSV for 099718235.jpg.
# No matching rows found in the CSV for 099720514.jpg.
# No matching rows found in the CSV for 099723507.jpg.
# No matching rows found in the CSV for 099723790.jpg.
# No matching rows found in the CSV for 099732061.jpg.
# No matching rows found in the CSV for 099734455.jpg.
# Image 099738113.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/automobile repair
# No matching rows found in the CSV for 099738249.jpg.
# No matching rows found in the CSV for 099742294.jpg.
# Image 099750250.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/sharpening tools
# No matching rows found in the CSV for 099750569.jpg.
# Image 099751375.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/painting
# No matching rows found in the CSV for 099754776.jpg.
# No matching rows found in the CSV for 099762830.jpg.
# No matching rows found in the CSV for 099765034.jpg.
# No matching rows found in the CSV for 099767226.jpg.
# No matching rows found in the CSV for 099769622.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/water volleyball does not exist.
# No matching rows found in the CSV for 099774939.jpg.
# No matching rows found in the CSV for 099778439.jpg.
# No matching rows found in the CSV for 099782086.jpg.
# Image 099788471.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/marching band
# Image 099789785.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cricket
# No matching rows found in the CSV for 099790932.jpg.
# No matching rows found in the CSV for 099791513.jpg.
# Image 099793411.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/hacky sack
# No matching rows found in the CSV for 099795672.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/billiards does not exist.
# No matching rows found in the CSV for 099817474.jpg.
# Image 099819788.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bicycling
# Image 099825179.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/cricket
# No matching rows found in the CSV for 099826898.jpg.
# Image 099830316.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bicycling
# Image 099830693.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/farming, cultivating field
# Image 099834751.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/carpentry
# Image 099842123.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skiing
# No matching rows found in the CSV for 099852511.jpg.
# Image 099856025.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skateboarding
# No matching rows found in the CSV for 099856081.jpg.
# No matching rows found in the CSV for 099861143.jpg.
# Image 099861732.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/accordion
# Image 099864788.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/carpentry
# No matching rows found in the CSV for 099865392.jpg.
# Image 099869425.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/bicycling
# Image 099869848.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/garbage collector, walking, dumping bins into truck
# No matching rows found in the CSV for 099875003.jpg.
# No matching rows found in the CSV for 099879285.jpg.
# Image 099879294.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/moving furniture, household items, carrying boxes
# No matching rows found in the CSV for 099882606.jpg.
# No matching rows found in the CSV for 099884483.jpg.
# No matching rows found in the CSV for 099889261.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/hockey, field does not exist.
# Image 099894296.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# Image 099914957.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/farming, rice, planting, grain milling activities
# Image 099920730.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/gardening
# Image 099927653.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/coaching
# No matching rows found in the CSV for 099929948.jpg.
# No matching rows found in the CSV for 099933512.jpg.
# No matching rows found in the CSV for 099935030.jpg.
# No matching rows found in the CSV for 099941373.jpg.
# No matching rows found in the CSV for 099945052.jpg.
# Image 099945907.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/fishing
# Image 099946068.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/masonry, concrete
# No matching rows found in the CSV for 099950519.jpg.
# Image 099955770.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/chopping wood
# No matching rows found in the CSV for 099965631.jpg.
# Image 099967321.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/massage therapist
# No matching rows found in the CSV for 099971767.jpg.
# Image 099980514.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/skateboarding
# No matching rows found in the CSV for 099987144.jpg.
# Activity folder C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/hanging storm windows does not exist.
# Image 099992483.jpg copied to C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/yoga
# Image copying completed!
# 45

# %%
import os

# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/"

# Initialize a counter for subdirectories
subdirectory_count = 0

# Iterate through each subdirectory
for subdirectory in os.listdir(main_directory):
    subdirectory_path = os.path.join(main_directory, subdirectory)
    
    if os.path.isdir(subdirectory_path):
        # Count the number of image files in the subdirectory
        total_files = len(os.listdir(subdirectory_path))
        
        # Increment the subdirectory count
        subdirectory_count += 1
        
        # Print the results
        print(f"Subdirectory: {subdirectory}")
        print(f"Total files: {total_files}")
        print()

# Print the total number of subdirectories
print(f"Total subdirectories: {subdirectory_count}")
# Out:
# Subdirectory: .ipynb_checkpoints
# Total files: 0
#
# Subdirectory: accordion
# Total files: 31
#
# Subdirectory: aerobic
# Total files: 266
#
# Subdirectory: archery, non-hunting
# Total files: 53
#
# Subdirectory: automobile repair
# Total files: 48
#
# Subdirectory: backpacking
# Total files: 105
#
# Subdirectory: badminton
# Total files: 83
#
# Subdirectory: bakery, general
# Total files: 71
#
# Subdirectory: ballet, modern, or jazz
# Total files: 156
#
# Subdirectory: basketball
# Total files: 170
#
# Subdirectory: bicycling
# Total files: 598
#
# Subdirectory: bowling
# Total files: 50
#
# Subdirectory: boxing
# Total files: 49
#
# Subdirectory: boxing, punching bag
# Total files: 35
#
# Subdirectory: broomball
# Total files: 35
#
# Subdirectory: calisthenics
# Total files: 114
#
# Subdirectory: canoeing
# Total files: 251
#
# Subdirectory: carpentry
# Total files: 393
#
# Subdirectory: carrying, loading or stacking wood
# Total files: 30
#
# Subdirectory: child care
# Total files: 74
#
# Subdirectory: chopping wood
# Total files: 86
#
# Subdirectory: cleaning
# Total files: 84
#
# Subdirectory: cleaning gutters
# Total files: 30
#
# Subdirectory: cleaning windows, washing windows, general
# Total files: 40
#
# Subdirectory: cleaning, sweeping floor or carpet
# Total files: 27
#
# Subdirectory: climbing hills
# Total files: 28
#
# Subdirectory: coaching
# Total files: 59
#
# Subdirectory: coal mining
# Total files: 28
#
# Subdirectory: cooking or food preparation
# Total files: 206
#
# Subdirectory: cricket
# Total files: 34
#
# Subdirectory: dancing
# Total files: 122
#
# Subdirectory: dog sledding
# Total files: 47
#
# Subdirectory: driving tractor
# Total files: 60
#
# Subdirectory: drums, sitting
# Total files: 56
#
# Subdirectory: eating
# Total files: 68
#
# Subdirectory: elder care
# Total files: 30
#
# Subdirectory: farming
# Total files: 53
#
# Subdirectory: farming, cultivating field
# Total files: 43
#
# Subdirectory: farming, feeding cattle, horses
# Total files: 34
#
# Subdirectory: farming, rice, planting, grain milling activities
# Total files: 59
#
# Subdirectory: fencing
# Total files: 54
#
# Subdirectory: fire fighter
# Total files: 63
#
# Subdirectory: fishing
# Total files: 528
#
# Subdirectory: food shopping with or without a grocery cart
# Total files: 31
#
# Subdirectory: football
# Total files: 193
#
# Subdirectory: frisbee
# Total files: 87
#
# Subdirectory: garbage collector, walking, dumping bins into truck
# Total files: 62
#
# Subdirectory: gardening
# Total files: 609
#
# Subdirectory: golf
# Total files: 138
#
# Subdirectory: guitar rock and roll band
# Total files: 37
#
# Subdirectory: guitar, classical, folk, sitting
# Total files: 50
#
# Subdirectory: gymnastics
# Total files: 49
#
# Subdirectory: hacky sack
# Total files: 46
#
# Subdirectory: hairstylist (e.g., plaiting hair, manicure, make-up artist)
# Total files: 64
#
# Subdirectory: hiking
# Total files: 29
#
# Subdirectory: horse grooming, feeding, cleaning, harnessing and unharnessing
# Total files: 123
#
# Subdirectory: horseback riding
# Total files: 200
#
# Subdirectory: hunting
# Total files: 122
#
# Subdirectory: ironing
# Total files: 52
#
# Subdirectory: jai alai
# Total files: 53
#
# Subdirectory: juggling
# Total files: 34
#
# Subdirectory: kitchen activity
# Total files: 51
#
# Subdirectory: lacrosse
# Total files: 34
#
# Subdirectory: landry
# Total files: 57
#
# Subdirectory: laundry worker
# Total files: 53
#
# Subdirectory: laying or removing carpet
# Total files: 45
#
# Subdirectory: making bed
# Total files: 59
#
# Subdirectory: marching band
# Total files: 40
#
# Subdirectory: masonry, concrete
# Total files: 53
#
# Subdirectory: massage therapist
# Total files: 65
#
# Subdirectory: mopping
# Total files: 48
#
# Subdirectory: moto-cross, off-road motor sports, all-terrain vehicle, general
# Total files: 33
#
# Subdirectory: moving furniture, household items, carrying boxes
# Total files: 59
#
# Subdirectory: paddle boarding
# Total files: 44
#
# Subdirectory: paddleball
# Total files: 120
#
# Subdirectory: painting
# Total files: 171
#
# Subdirectory: pilates, general
# Total files: 85
#
# Subdirectory: playing chess game
# Total files: 34
#
# Subdirectory: playing table tennis
# Total files: 29
#
# Subdirectory: playing with animals
# Total files: 93
#
# Subdirectory: playing with children
# Total files: 79
#
# Subdirectory: rock climbing
# Total files: 145
#
# Subdirectory: rollerblading
# Total files: 89
#
# Subdirectory: roofing
# Total files: 53
#
# Subdirectory: rope skipping
# Total files: 155
#
# Subdirectory: rugby, touch, non-competitive
# Total files: 33
#
# Subdirectory: running
# Total files: 167
#
# Subdirectory: running, stairs, up
# Total files: 29
#
# Subdirectory: scraping and painting sailboat or powerboat
# Total files: 31
#
# Subdirectory: serving food and drinks
# Total files: 57
#
# Subdirectory: sharpening tools
# Total files: 56
#
# Subdirectory: shoe repair, general
# Total files: 38
#
# Subdirectory: shoveling snow, by hand
# Total files: 48
#
# Subdirectory: sitting
# Total files: 139
#
# Subdirectory: skateboarding
# Total files: 184
#
# Subdirectory: skating, ice
# Total files: 113
#
# Subdirectory: skating, speed, competitive
# Total files: 37
#
# Subdirectory: skiing
# Total files: 355
#
# Subdirectory: skiing, water or wakeboarding (Taylor Code 220)
# Total files: 33
#
# Subdirectory: skydiving, base jumping, bungee jumping
# Total files: 48
#
# Subdirectory: slide board exercise, general
# Total files: 45
#
# Subdirectory: slimnastics, jazzercise
# Total files: 29
#
# Subdirectory: snow shoeing
# Total files: 42
#
# Subdirectory: snowmobiling
# Total files: 37
#
# Subdirectory: squash
# Total files: 68
#
# Subdirectory: stretching, mild
# Total files: 65
#
# Subdirectory: surfing
# Total files: 41
#
# Subdirectory: swimming
# Total files: 235
#
# Subdirectory: tailoring
# Total files: 110
#
# Subdirectory: tennis
# Total files: 153
#
# Subdirectory: therapeutic exercise ball, Fitball exercise
# Total files: 86
#
# Subdirectory: touringtravelingvacation involving riding in a vehicle
# Total files: 56
#
# Subdirectory: track and field
# Total files: 41
#
# Subdirectory: truck driving
# Total files: 51
#
# Subdirectory: vacuuming, general, moderate effort
# Total files: 50
#
# Subdirectory: video exercise workouts, TV conditioning programs
# Total files: 151
#
# Subdirectory: violin, sitting
# Total files: 42
#
# Subdirectory: volleyball
# Total files: 93
#
# Subdirectory: walking
# Total files: 154
#
# Subdirectory: walking the dog
# Total files: 33
#
# Subdirectory: wash dishes
# Total files: 51
#
# Subdirectory: washing and waxing car
# Total files: 82
#
# Subdirectory: washing fence, painting fence, moderate effort
# Total files: 33
#
# Subdirectory: water walking
# Total files: 62
#
# Subdirectory: weight lifting, power lifting
# Total files: 31
#
# Subdirectory: windsurfing
# Total files: 68
#
# Subdirectory: yard work, general
# Total files: 29
#
# Subdirectory: yoga
# Total files: 340
#
# Total subdirectories: 128

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import Image

# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/"

# Data augmentation parameters
augmentation_params = {
    'rotation_range': 20,
    'width_shift_range': 0.2,
    'height_shift_range': 0.2,
    'shear_range': 0.2,
    'zoom_range': 0.2,
    'horizontal_flip': True
}

# Target image size
target_size = (224, 224)

# Iterate through each subdirectory
for subdirectory in os.listdir(main_directory):
    subdirectory_path = os.path.join(main_directory, subdirectory)
    
    if os.path.isdir(subdirectory_path):
        # Create an ImageDataGenerator with augmentation parameters
        datagen = ImageDataGenerator(**augmentation_params)
        
        # Get a list of image files within the subdirectory
        image_files = [filename for filename in os.listdir(subdirectory_path) if os.path.isfile(os.path.join(subdirectory_path, filename))]
        
        # Iterate through each image file and apply data augmentation
        for image_file in image_files:
            image_path = os.path.join(subdirectory_path, image_file)
            
            # Load the image
            image = Image.open(image_path)
            
            # Resize the image to the target size
            image = image.resize(target_size)
            
            # Convert the image to a NumPy array
            image_array = np.array(image)
            
            # Generate augmented image
            augmented_image = datagen.flow(image_array.reshape(1, *image_array.shape), batch_size=1).next()[0].astype(np.uint8)
            
            # Convert augmented image back to PIL image
            augmented_image = Image.fromarray(augmented_image)
            
            # Save the augmented image
            augmented_image_path = os.path.join(subdirectory_path, "augmented_" + image_file)
            augmented_image.save(augmented_image_path)

print("Data augmentation applied successfully!")
# Out:
# Data augmentation applied successfully!

# %%
import os
import numpy as np
import tensorflow as tf
from PIL import Image

# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/"

# Data augmentation parameters
augmentation_params = {
    'brightness': 0.4,
    'contrast': 1.0,
    'jpeg_quality': [80, 100],
    'saturation': 0.5
}

# Target image size
target_size = (224, 224)

# Iterate through each subdirectory
for subdirectory in os.listdir(main_directory):
    subdirectory_path = os.path.join(main_directory, subdirectory)
    
    if os.path.isdir(subdirectory_path):
        # Get a list of image files within the subdirectory
        image_files = [filename for filename in os.listdir(subdirectory_path) if os.path.isfile(os.path.join(subdirectory_path, filename))]
        
        # Iterate through each image file and apply data augmentation
        for image_file in image_files:
            image_path = os.path.join(subdirectory_path, image_file)
            
            # Load and preprocess the image
            image = Image.open(image_path)
            image_tensor = tf.convert_to_tensor(np.array(image))
            image_tensor = tf.image.resize(image_tensor, target_size)
            image_tensor = tf.cast(image_tensor, tf.float32) / 255.0  # Normalize pixel values
            
            # Apply data augmentation
            augmented_image = tf.image.stateless_random_brightness(image_tensor, max_delta=augmentation_params['brightness'], seed=(1, 2))
            augmented_image = tf.image.stateless_random_contrast(augmented_image, lower=1 - augmentation_params['contrast'], upper=1 + augmentation_params['contrast'], seed=(1, 2))
            augmented_image = tf.image.stateless_random_jpeg_quality(augmented_image, min_jpeg_quality=augmentation_params['jpeg_quality'][0], max_jpeg_quality=augmentation_params['jpeg_quality'][1], seed=(1, 2))
            augmented_image = tf.image.stateless_random_saturation(augmented_image, lower=1 - augmentation_params['saturation'], upper=1 + augmentation_params['saturation'], seed=(1, 2))
            
            # Convert augmented image back to PIL image
            augmented_image = tf.clip_by_value(augmented_image * 255.0, 0.0, 255.0)
            augmented_image = tf.cast(augmented_image, tf.uint8)
            augmented_image = Image.fromarray(augmented_image.numpy())
            
            # Generate a new file name for the augmented image
            augmented_image_file = "col_" + image_file
            
            # Save the augmented image with the new file name
            augmented_image_path = os.path.join(subdirectory_path, augmented_image_file)
            augmented_image.save(augmented_image_path)

# %%
import os

# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/"

# Initialize a counter for images
image_count = 0

# Iterate through each subdirectory in the main directory
for subdirectory in os.listdir(main_directory):
    subdirectory_path = os.path.join(main_directory, subdirectory)
    
    if os.path.isdir(subdirectory_path):
        # Count the number of image files in the subdirectory
        subdirectory_images = [filename for filename in os.listdir(subdirectory_path) if filename.lower().endswith(('.jpg', '.jpeg', '.png', '.gif'))]
        subdirectory_image_count = len(subdirectory_images)
        
        # Increment the image count
        image_count += subdirectory_image_count

# Print the total number of images
print(f"Total number of images: {image_count}")
# Out:
# Total number of images: 47080

# %%
import os
import random
import shutil
from math import ceil

def move_images(original_directory, duplicate_directory):
    # Iterate through each subdirectory in the original directory
    for subdir in os.listdir(original_directory):
        original_subdir_path = os.path.join(original_directory, subdir)
        duplicate_subdir_path = os.path.join(duplicate_directory, subdir)
        
        # Create the corresponding subdirectory in the duplicate directory
        os.makedirs(duplicate_subdir_path, exist_ok=True)
        
        # Get the list of image files in the original subdirectory
        image_files = [file for file in os.listdir(original_subdir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Calculate the number of images to move (10% of total images rounded up)
        num_images_to_move = ceil(len(image_files) * 0.1)
        
        # Choose a random selection of images to move
        images_to_move = random.sample(image_files, num_images_to_move)
        
        # Move the selected images to the duplicate subdirectory
        for file in images_to_move:
            original_file_path = os.path.join(original_subdir_path, file)
            duplicate_file_path = os.path.join(duplicate_subdir_path, file)
            shutil.move(original_file_path, duplicate_file_path)

    print("Image movement completed successfully.")

# Provide the paths for the original directory and duplicate directory
original_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MOREVALID/"

# Call the function to move the images
move_images(original_directory, duplicate_directory)
# Out:
# Image movement completed successfully.

# %%
import os
import random
import shutil
from math import ceil

def move_images(original_directory, duplicate_directory):
    # Iterate through each subdirectory in the original directory
    for subdir in os.listdir(original_directory):
        original_subdir_path = os.path.join(original_directory, subdir)
        duplicate_subdir_path = os.path.join(duplicate_directory, subdir)
        
        # Create the corresponding subdirectory in the duplicate directory
        os.makedirs(duplicate_subdir_path, exist_ok=True)
        
        # Get the list of image files in the original subdirectory
        image_files = [file for file in os.listdir(original_subdir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Calculate the number of images to move (10% of total images rounded up)
        num_images_to_move = ceil(len(image_files) * 0.1)
        
        # Choose a random selection of images to move
        images_to_move = random.sample(image_files, num_images_to_move)
        
        # Move the selected images to the duplicate subdirectory
        for file in images_to_move:
            original_file_path = os.path.join(original_subdir_path, file)
            duplicate_file_path = os.path.join(duplicate_subdir_path, file)
            shutil.move(original_file_path, duplicate_file_path)

    print("Image movement completed successfully.")

# Provide the paths for the original directory and duplicate directory
original_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETEST/"

# Call the function to move the images
move_images(original_directory, duplicate_directory)
# Out:
# Image movement completed successfully.

# %%
import os

# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/"

# Initialize a counter for images
image_count = 0

# Iterate through each subdirectory in the main directory
for subdirectory in os.listdir(main_directory):
    subdirectory_path = os.path.join(main_directory, subdirectory)
    
    if os.path.isdir(subdirectory_path):
        # Count the number of image files in the subdirectory
        subdirectory_images = [filename for filename in os.listdir(subdirectory_path) if filename.lower().endswith(('.jpg', '.jpeg', '.png', '.gif'))]
        subdirectory_image_count = len(subdirectory_images)
        
        # Increment the image count
        image_count += subdirectory_image_count

# Print the total number of images
print(f"Total number of images: {image_count}")
# Out:
# Total number of images: 38023

# %%
import os

# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MOREVALID/"

# Initialize a counter for images
image_count = 0

# Iterate through each subdirectory in the main directory
for subdirectory in os.listdir(main_directory):
    subdirectory_path = os.path.join(main_directory, subdirectory)
    
    if os.path.isdir(subdirectory_path):
        # Count the number of image files in the subdirectory
        subdirectory_images = [filename for filename in os.listdir(subdirectory_path) if filename.lower().endswith(('.jpg', '.jpeg', '.png', '.gif'))]
        subdirectory_image_count = len(subdirectory_images)
        
        # Increment the image count
        image_count += subdirectory_image_count

# Print the total number of images
print(f"Total number of images: {image_count}")
# Out:
# Total number of images: 4763

# %%
import os

# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETEST/"

# Initialize a counter for images
image_count = 0

# Iterate through each subdirectory in the main directory
for subdirectory in os.listdir(main_directory):
    subdirectory_path = os.path.join(main_directory, subdirectory)
    
    if os.path.isdir(subdirectory_path):
        # Count the number of image files in the subdirectory
        subdirectory_images = [filename for filename in os.listdir(subdirectory_path) if filename.lower().endswith(('.jpg', '.jpeg', '.png', '.gif'))]
        subdirectory_image_count = len(subdirectory_images)
        
        # Increment the image count
        image_count += subdirectory_image_count

# Print the total number of images
print(f"Total number of images: {image_count}")
# Out:
# Total number of images: 4294

# %%
import os
import shutil

def duplicate_directory_structure(source_directory, target_directory):
    # Iterate through all directories and subdirectories in the source directory
    for root, dirs, files in os.walk(source_directory):
        # Get the relative path of the current directory from the source directory
        relative_path = os.path.relpath(root, source_directory)
        
        # Create the corresponding directory in the target directory
        target_subdirectory = os.path.join(target_directory, relative_path)
        os.makedirs(target_subdirectory, exist_ok=True)
        
    print("Directory structure duplicated successfully.")

# Provide the path for the source directory
source_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETEST/"

# Provide the path for the target directory (where you want to duplicate the structure)
target_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETEST_GRAY_SCALE/"

# Call the function to duplicate the directory structure
duplicate_directory_structure(source_directory, target_directory)
# Out:
# Directory structure duplicated successfully.

# %%
import os
import cv2
import shutil

def convert_to_grayscale(image_path):
    # Read the image
    image = cv2.imread(image_path)

    # Convert the image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Expand the dimensions to match the shape (224, 224, 1)
    gray_image = gray_image[:, :, None]

    return gray_image

def stack_channels(image_path, gray_image):
    # Read the original image
    original_image = cv2.imread(image_path)

    # Stack the grayscale image channels to create a final image
    final_image = cv2.merge([gray_image, gray_image, gray_image])

    return final_image

def copy_and_convert_images(main_directory, duplicate_directory):
    # Iterate through each subclass directory in the main directory
    for subclass_dir in os.listdir(main_directory):
        subclass_dir_path = os.path.join(main_directory, subclass_dir)
        duplicate_subclass_dir_path = os.path.join(duplicate_directory, subclass_dir)
        
        # Create the corresponding subclass directory in the duplicate directory
        os.makedirs(duplicate_subclass_dir_path, exist_ok=True)
        
        # Get the list of image files in the subclass directory
        image_files = [file for file in os.listdir(subclass_dir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Iterate through each image file
        for file in image_files:
            original_file_path = os.path.join(subclass_dir_path, file)
            duplicate_file_path = os.path.join(duplicate_subclass_dir_path, file)
            
            # Convert the image to grayscale
            gray_image = convert_to_grayscale(original_file_path)
            
            # Stack the grayscale channels to create the final image
            final_image = stack_channels(original_file_path, gray_image)
            
            # Save the final image to the duplicate subclass directory
            cv2.imwrite(duplicate_file_path, final_image)

    print("Image conversion and copying completed successfully.")

# Specify the paths for the main directory and duplicate directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN_GRAY_SCALE/"

# Call the function to copy and convert the images
copy_and_convert_images(main_directory, duplicate_directory)
# Out:
# Image conversion and copying completed successfully.

# %%
import os
import cv2
import shutil

def convert_to_grayscale(image_path):
    # Read the image
    image = cv2.imread(image_path)

    # Convert the image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Expand the dimensions to match the shape (224, 224, 1)
    gray_image = gray_image[:, :, None]

    return gray_image

def stack_channels(image_path, gray_image):
    # Read the original image
    original_image = cv2.imread(image_path)

    # Stack the grayscale image channels to create a final image
    final_image = cv2.merge([gray_image, gray_image, gray_image])

    return final_image

def copy_and_convert_images(main_directory, duplicate_directory):
    # Iterate through each subclass directory in the main directory
    for subclass_dir in os.listdir(main_directory):
        subclass_dir_path = os.path.join(main_directory, subclass_dir)
        duplicate_subclass_dir_path = os.path.join(duplicate_directory, subclass_dir)
        
        # Create the corresponding subclass directory in the duplicate directory
        os.makedirs(duplicate_subclass_dir_path, exist_ok=True)
        
        # Get the list of image files in the subclass directory
        image_files = [file for file in os.listdir(subclass_dir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Iterate through each image file
        for file in image_files:
            original_file_path = os.path.join(subclass_dir_path, file)
            duplicate_file_path = os.path.join(duplicate_subclass_dir_path, file)
            
            # Convert the image to grayscale
            gray_image = convert_to_grayscale(original_file_path)
            
            # Stack the grayscale channels to create the final image
            final_image = stack_channels(original_file_path, gray_image)
            
            # Save the final image to the duplicate subclass directory
            cv2.imwrite(duplicate_file_path, final_image)

    print("Image conversion and copying completed successfully.")

# Specify the paths for the main directory and duplicate directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MOREVALID/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MOREVALID_GRAY_SCALE/"

# Call the function to copy and convert the images
copy_and_convert_images(main_directory, duplicate_directory)
# Out:
# Image conversion and copying completed successfully.

# %%
import os
import cv2
import shutil

def convert_to_grayscale(image_path):
    # Read the image
    image = cv2.imread(image_path)

    # Convert the image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Expand the dimensions to match the shape (224, 224, 1)
    gray_image = gray_image[:, :, None]

    return gray_image

def stack_channels(image_path, gray_image):
    # Read the original image
    original_image = cv2.imread(image_path)

    # Stack the grayscale image channels to create a final image
    final_image = cv2.merge([gray_image, gray_image, gray_image])

    return final_image

def copy_and_convert_images(main_directory, duplicate_directory):
    # Iterate through each subclass directory in the main directory
    for subclass_dir in os.listdir(main_directory):
        subclass_dir_path = os.path.join(main_directory, subclass_dir)
        duplicate_subclass_dir_path = os.path.join(duplicate_directory, subclass_dir)
        
        # Create the corresponding subclass directory in the duplicate directory
        os.makedirs(duplicate_subclass_dir_path, exist_ok=True)
        
        # Get the list of image files in the subclass directory
        image_files = [file for file in os.listdir(subclass_dir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Iterate through each image file
        for file in image_files:
            original_file_path = os.path.join(subclass_dir_path, file)
            duplicate_file_path = os.path.join(duplicate_subclass_dir_path, file)
            
            # Convert the image to grayscale
            gray_image = convert_to_grayscale(original_file_path)
            
            # Stack the grayscale channels to create the final image
            final_image = stack_channels(original_file_path, gray_image)
            
            # Save the final image to the duplicate subclass directory
            cv2.imwrite(duplicate_file_path, final_image)

    print("Image conversion and copying completed successfully.")

# Specify the paths for the main directory and duplicate directory
main_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETEST/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETEST_GRAY_SCALE/"

# Call the function to copy and convert the images
copy_and_convert_images(main_directory, duplicate_directory)
# Out:
# Image conversion and copying completed successfully.

# %%
import shutil

folder_path = "C:/Users/Prasanna P M/Human Project/Project U Turn/MORETRAIN/"  # Replace with the path to the folder you want to delete

try:
    shutil.rmtree(folder_path)
    print("Folder and its contents deleted successfully.")
except OSError as e:
    print(f"Error: {e.strerror}")
# Out:
# Folder and its contents deleted successfully.
