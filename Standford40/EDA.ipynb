# %%
import zipfile

# Specify the path to the ZIP file
zip_file_path = 'C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human+Action+Recognition-20220526T101201Z-001.zip'

# Specify the directory where you want to extract the contents
extract_dir = 'C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/'

# Open the ZIP file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all the contents to the specified directory
    zip_ref.extractall(extract_dir)
    
print("Folder extracted successfully.")
# Out:
# Folder extracted successfully.

# %%
import os

# Activity names
activities = [
    "applauding",
    "blowing_bubbles",
    "brushing_teeth",
    "cleaning_the_floor",
    "climbing",
    "cooking",
    "cutting_trees",
    "cutting_vegetables",
    "drinking",
    "feeding_a_horse",
    "fishing",
    "fixing_a_bike",
    "fixing_a_car",
    "gardening",
    "holding_an_umbrella",
    "jumping",
    "looking_through_a_microscope",
    "looking_through_a_telescope",
    "playing_guitar",
    "playing_violin",
    "pouring_liquid",
    "pushing_a_cart",
    "reading",
    "phoning",
    "riding_a_bike",
    "riding_a_horse",
    "rowing_a_boat",
    "running",
    "shooting_an_arrow",
    "smoking",
    "taking_photos",
    "texting_message",
    "throwing_frisby",
    "using_a_computer",
    "walking_the_dog",
    "washing_dishes",
    "watching_TV",
    "waving_hands",
    "writing_on_a_board",
    "writing_on_a_book"
]



# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TRAIN/"

# Create subfolders based on activity names
for activity in activities:
    subfolder_path = os.path.join(main_directory, activity)
    os.makedirs(subfolder_path, exist_ok=True)

print("Subfolders created successfully!")
# Out:
# Subfolders created successfully!

# %%
import os
import shutil

data_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/JPEGImages/"
main_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TRAIN/"


# Iterate through the images in the data directory
for image_file in os.listdir(data_directory):
    image_path = os.path.join(data_directory, image_file)
    
    # Extract the subclass folder name from the image file name
    parts = image_file.split("_")
    subclass_folder = "_".join(parts[:-1]) if len(parts) > 2 else parts[0]
    
    # Check if the subclass folder exists in the main directory
    subclass_directory = os.path.join(main_directory, subclass_folder)
    if os.path.exists(subclass_directory):
        # Move the image to the corresponding subclass folder
        destination_path = os.path.join(subclass_directory, image_file)
        shutil.move(image_path, destination_path)
        print(f"Moved image '{image_file}' to '{subclass_folder}' subclass folder.")
    else:
        print(f"Subclass folder '{subclass_folder}' does not exist in the main directory.")
# Out:
# Moved image 'applauding_001.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_002.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_003.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_004.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_005.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_006.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_007.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_008.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_009.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_010.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_011.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_012.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_013.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_014.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_015.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_016.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_017.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_018.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_019.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_020.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_021.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_022.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_023.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_024.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_025.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_026.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_027.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_028.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_029.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_030.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_031.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_032.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_033.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_034.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_035.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_036.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_037.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_038.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_039.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_040.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_041.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_042.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_043.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_044.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_045.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_046.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_047.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_048.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_049.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_050.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_051.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_052.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_053.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_054.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_055.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_056.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_057.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_058.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_059.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_060.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_061.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_062.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_063.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_064.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_065.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_066.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_067.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_068.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_069.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_070.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_071.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_072.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_073.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_074.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_075.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_076.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_077.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_078.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_079.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_080.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_081.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_082.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_083.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_084.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_085.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_086.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_087.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_088.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_089.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_090.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_091.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_092.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_093.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_094.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_095.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_096.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_097.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_098.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_099.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_100.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_101.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_102.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_103.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_104.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_105.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_106.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_107.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_108.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_109.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_110.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_111.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_112.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_113.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_114.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_115.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_116.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_117.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_118.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_119.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_120.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_121.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_122.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_123.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_124.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_125.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_126.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_127.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_128.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_129.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_130.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_131.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_132.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_133.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_134.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_135.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_136.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_137.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_138.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_139.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_140.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_141.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_142.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_143.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_144.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_145.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_146.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_147.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_148.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_149.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_150.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_151.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_152.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_153.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_154.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_155.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_156.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_157.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_158.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_159.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_160.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_161.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_162.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_163.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_164.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_165.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_166.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_167.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_168.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_169.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_170.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_171.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_172.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_173.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_174.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_175.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_176.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_177.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_178.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_179.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_180.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_181.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_182.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_183.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_184.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_185.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_186.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_187.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_188.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_189.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_190.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_191.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_192.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_193.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_194.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_195.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_196.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_197.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_198.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_199.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_200.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_201.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_202.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_203.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_204.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_205.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_206.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_207.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_208.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_209.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_210.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_211.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_212.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_213.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_214.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_215.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_216.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_217.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_218.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_219.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_220.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_221.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_222.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_223.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_224.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_225.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_226.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_227.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_228.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_229.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_230.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_231.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_232.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_233.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_234.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_235.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_236.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_237.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_238.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_239.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_240.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_241.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_242.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_243.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_244.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_245.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_246.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_247.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_248.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_249.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_250.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_251.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_252.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_253.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_254.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_255.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_256.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_257.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_258.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_259.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_260.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_261.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_262.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_263.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_264.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_265.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_266.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_267.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_268.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_269.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_270.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_271.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_272.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_273.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_274.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_275.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_276.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_277.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_278.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_279.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_280.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_281.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_282.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_283.jpg' to 'applauding' subclass folder.
# Moved image 'applauding_284.jpg' to 'applauding' subclass folder.
# Moved image 'blowing_bubbles_001.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_002.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_003.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_004.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_005.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_006.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_007.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_008.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_009.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_010.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_011.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_012.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_013.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_014.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_015.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_016.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_017.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_018.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_019.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_020.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_021.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_022.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_023.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_024.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_025.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_026.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_027.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_028.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_029.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_030.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_031.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_032.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_033.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_034.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_035.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_036.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_037.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_038.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_039.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_040.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_041.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_042.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_043.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_044.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_045.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_046.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_047.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_048.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_049.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_050.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_051.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_052.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_053.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_054.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_055.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_056.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_057.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_058.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_059.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_060.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_061.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_062.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_063.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_064.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_065.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_066.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_067.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_068.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_069.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_070.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_071.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_072.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_073.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_074.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_075.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_076.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_077.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_078.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_079.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_080.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_081.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_082.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_083.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_084.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_085.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_086.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_087.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_088.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_089.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_090.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_091.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_092.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_093.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_094.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_095.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_096.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_097.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_098.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_099.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_100.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_101.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_102.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_103.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_104.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_105.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_106.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_107.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_108.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_109.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_110.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_111.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_112.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_113.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_114.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_115.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_116.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_117.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_118.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_119.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_120.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_121.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_122.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_123.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_124.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_125.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_126.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_127.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_128.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_129.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_130.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_131.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_132.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_133.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_134.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_135.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_136.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_137.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_138.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_139.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_140.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_141.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_142.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_143.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_144.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_145.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_146.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_147.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_148.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_149.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_150.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_151.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_152.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_153.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_154.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_155.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_156.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_157.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_158.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_159.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_160.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_161.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_162.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_163.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_164.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_165.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_166.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_167.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_168.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_169.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_170.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_171.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_172.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_173.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_174.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_175.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_176.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_177.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_178.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_179.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_180.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_181.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_182.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_183.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_184.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_185.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_186.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_187.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_188.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_189.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_190.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_191.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_192.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_193.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_194.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_195.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_196.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_197.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_198.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_199.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_200.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_201.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_202.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_203.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_204.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_205.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_206.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_207.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_208.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_209.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_210.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_211.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_212.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_213.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_214.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_215.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_216.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_217.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_218.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_219.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_220.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_221.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_222.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_223.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_224.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_225.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_226.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_227.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_228.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_229.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_230.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_231.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_232.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_233.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_234.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_235.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_236.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_237.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_238.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_239.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_240.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_241.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_242.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_243.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_244.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_245.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_246.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_247.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_248.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_249.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_250.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_251.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_252.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_253.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_254.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_255.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_256.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_257.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_258.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'blowing_bubbles_259.jpg' to 'blowing_bubbles' subclass folder.
# Moved image 'brushing_teeth_001.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_002.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_003.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_004.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_005.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_006.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_007.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_008.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_009.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_010.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_011.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_012.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_013.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_014.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_015.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_016.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_017.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_018.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_019.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_020.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_021.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_022.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_023.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_024.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_025.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_026.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_027.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_028.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_029.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_030.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_031.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_032.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_033.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_034.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_035.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_036.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_037.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_038.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_039.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_040.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_041.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_042.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_043.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_044.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_045.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_046.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_047.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_048.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_049.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_050.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_051.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_052.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_053.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_054.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_055.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_056.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_057.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_058.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_059.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_060.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_061.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_062.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_063.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_064.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_065.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_066.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_067.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_068.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_069.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_070.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_071.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_072.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_073.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_074.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_075.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_076.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_077.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_078.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_079.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_080.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_081.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_082.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_083.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_084.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_085.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_086.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_087.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_088.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_089.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_090.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_091.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_092.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_093.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_094.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_095.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_096.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_097.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_098.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_099.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_100.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_101.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_102.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_103.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_104.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_105.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_106.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_107.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_108.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_109.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_110.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_111.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_112.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_113.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_114.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_115.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_116.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_117.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_118.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_119.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_120.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_121.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_122.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_123.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_124.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_125.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_126.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_127.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_128.jpg' to 'brushing_teeth' subclass folder.
# Moved image 'brushing_teeth_129.jpg' to 'brushing_teeth' subclass folder.
# ...
# Moved image 'writing_on_a_book_047.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_048.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_049.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_050.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_051.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_052.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_053.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_054.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_055.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_056.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_057.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_058.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_059.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_060.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_061.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_062.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_063.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_064.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_065.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_066.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_067.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_068.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_069.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_070.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_071.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_072.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_073.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_074.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_075.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_076.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_077.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_078.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_079.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_080.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_081.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_082.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_083.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_084.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_085.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_086.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_087.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_088.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_089.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_090.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_091.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_092.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_093.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_094.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_095.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_096.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_097.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_098.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_099.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_100.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_101.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_102.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_103.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_104.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_105.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_106.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_107.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_108.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_109.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_110.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_111.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_112.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_113.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_114.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_115.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_116.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_117.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_118.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_119.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_120.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_121.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_122.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_123.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_124.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_125.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_126.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_127.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_128.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_129.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_130.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_131.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_132.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_133.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_134.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_135.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_136.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_137.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_138.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_139.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_140.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_141.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_142.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_143.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_144.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_145.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_146.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_147.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_148.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_149.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_150.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_151.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_152.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_153.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_154.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_155.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_156.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_157.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_158.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_159.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_160.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_161.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_162.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_163.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_164.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_165.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_166.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_167.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_168.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_169.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_170.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_171.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_172.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_173.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_174.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_175.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_176.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_177.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_178.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_179.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_180.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_181.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_182.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_183.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_184.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_185.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_186.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_187.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_188.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_189.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_190.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_191.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_192.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_193.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_194.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_195.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_196.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_197.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_198.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_199.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_200.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_201.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_202.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_203.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_204.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_205.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_206.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_207.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_208.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_209.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_210.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_211.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_212.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_213.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_214.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_215.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_216.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_217.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_218.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_219.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_220.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_221.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_222.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_223.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_224.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_225.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_226.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_227.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_228.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_229.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_230.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_231.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_232.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_233.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_234.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_235.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_236.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_237.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_238.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_239.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_240.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_241.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_242.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_243.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_244.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_245.jpg' to 'writing_on_a_book' subclass folder.
# Moved image 'writing_on_a_book_246.jpg' to 'writing_on_a_book' subclass folder.

# %%
import os
import random
import shutil
from math import ceil

def move_images(original_directory, duplicate_directory):
    # Iterate through each subdirectory in the original directory
    for subdir in os.listdir(original_directory):
        original_subdir_path = os.path.join(original_directory, subdir)
        duplicate_subdir_path = os.path.join(duplicate_directory, subdir)
        
        # Create the corresponding subdirectory in the duplicate directory
        os.makedirs(duplicate_subdir_path, exist_ok=True)
        
        # Get the list of image files in the original subdirectory
        image_files = [file for file in os.listdir(original_subdir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Calculate the number of images to move (10% of total images rounded up)
        num_images_to_move = ceil(len(image_files) * 0.1)
        
        # Choose a random selection of images to move
        images_to_move = random.sample(image_files, num_images_to_move)
        
        # Move the selected images to the duplicate subdirectory
        for file in images_to_move:
            original_file_path = os.path.join(original_subdir_path, file)
            duplicate_file_path = os.path.join(duplicate_subdir_path, file)
            shutil.move(original_file_path, duplicate_file_path)

    print("Image movement completed successfully.")

# Provide the paths for the original directory and duplicate directory
original_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TRAIN/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/VALID/"

# Call the function to move the images
move_images(original_directory, duplicate_directory)
# Out:
# Image movement completed successfully.

# %%
import os
import random
import shutil
from math import ceil

def move_images(original_directory, duplicate_directory):
    # Iterate through each subdirectory in the original directory
    for subdir in os.listdir(original_directory):
        original_subdir_path = os.path.join(original_directory, subdir)
        duplicate_subdir_path = os.path.join(duplicate_directory, subdir)
        
        # Create the corresponding subdirectory in the duplicate directory
        os.makedirs(duplicate_subdir_path, exist_ok=True)
        
        # Get the list of image files in the original subdirectory
        image_files = [file for file in os.listdir(original_subdir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Calculate the number of images to move (10% of total images rounded up)
        num_images_to_move = ceil(len(image_files) * 0.1)
        
        # Choose a random selection of images to move
        images_to_move = random.sample(image_files, num_images_to_move)
        
        # Move the selected images to the duplicate subdirectory
        for file in images_to_move:
            original_file_path = os.path.join(original_subdir_path, file)
            duplicate_file_path = os.path.join(duplicate_subdir_path, file)
            shutil.move(original_file_path, duplicate_file_path)

    print("Image movement completed successfully.")

# Provide the paths for the original directory and duplicate directory
original_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TRAIN/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TEST/"

# Call the function to move the images
move_images(original_directory, duplicate_directory)
# Out:
# Image movement completed successfully.

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import Image

# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TRAIN/"

# Data augmentation parameters
augmentation_params = {
    'rotation_range': 20,
    'width_shift_range': 0.2,
    'height_shift_range': 0.2,
    'shear_range': 0.2,
    'zoom_range': 0.2,
    'horizontal_flip': True
}

# Target image size
target_size = (224, 224)

# Iterate through each subdirectory
for subdirectory in os.listdir(main_directory):
    subdirectory_path = os.path.join(main_directory, subdirectory)
    
    if os.path.isdir(subdirectory_path):
        # Create an ImageDataGenerator with augmentation parameters
        datagen = ImageDataGenerator(**augmentation_params)
        
        # Get a list of image files within the subdirectory
        image_files = [filename for filename in os.listdir(subdirectory_path) if os.path.isfile(os.path.join(subdirectory_path, filename))]
        
        # Iterate through each image file and apply data augmentation
        for image_file in image_files:
            image_path = os.path.join(subdirectory_path, image_file)
            
            # Load the image
            image = Image.open(image_path)
            
            # Resize the image to the target size
            image = image.resize(target_size)
            
            # Convert the image to a NumPy array
            image_array = np.array(image)
            
            # Generate augmented image
            augmented_image = datagen.flow(image_array.reshape(1, *image_array.shape), batch_size=1).next()[0].astype(np.uint8)
            
            # Convert augmented image back to PIL image
            augmented_image = Image.fromarray(augmented_image)
            
            # Save the augmented image
            augmented_image_path = os.path.join(subdirectory_path, "augmented_" + image_file)
            augmented_image.save(augmented_image_path)

print("Data augmentation applied successfully!")
# Out:
# Data augmentation applied successfully!

# %%
import os
import numpy as np
import tensorflow as tf
from PIL import Image

# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TRAIN/"

# Data augmentation parameters
augmentation_params = {
    'brightness': 0.4,
    'contrast': 1.0,
    'jpeg_quality': [80, 100],
    'saturation': 0.5
}

# Target image size
target_size = (224, 224)

# Iterate through each subdirectory
for subdirectory in os.listdir(main_directory):
    subdirectory_path = os.path.join(main_directory, subdirectory)
    
    if os.path.isdir(subdirectory_path):
        # Get a list of image files within the subdirectory
        image_files = [filename for filename in os.listdir(subdirectory_path) if os.path.isfile(os.path.join(subdirectory_path, filename))]
        
        # Iterate through each image file and apply data augmentation
        for image_file in image_files:
            image_path = os.path.join(subdirectory_path, image_file)
            
            # Load and preprocess the image
            image = Image.open(image_path)
            image_tensor = tf.convert_to_tensor(np.array(image))
            image_tensor = tf.image.resize(image_tensor, target_size)
            image_tensor = tf.cast(image_tensor, tf.float32) / 255.0  # Normalize pixel values
            
            # Apply data augmentation
            augmented_image = tf.image.stateless_random_brightness(image_tensor, max_delta=augmentation_params['brightness'], seed=(1, 2))
            augmented_image = tf.image.stateless_random_contrast(augmented_image, lower=1 - augmentation_params['contrast'], upper=1 + augmentation_params['contrast'], seed=(1, 2))
            augmented_image = tf.image.stateless_random_jpeg_quality(augmented_image, min_jpeg_quality=augmentation_params['jpeg_quality'][0], max_jpeg_quality=augmentation_params['jpeg_quality'][1], seed=(1, 2))
            augmented_image = tf.image.stateless_random_saturation(augmented_image, lower=1 - augmentation_params['saturation'], upper=1 + augmentation_params['saturation'], seed=(1, 2))
            
            # Convert augmented image back to PIL image
            augmented_image = tf.clip_by_value(augmented_image * 255.0, 0.0, 255.0)
            augmented_image = tf.cast(augmented_image, tf.uint8)
            augmented_image = Image.fromarray(augmented_image.numpy())
            
            # Generate a new file name for the augmented image
            augmented_image_file = "col_" + image_file
            
            # Save the augmented image with the new file name
            augmented_image_path = os.path.join(subdirectory_path, augmented_image_file)
            augmented_image.save(augmented_image_path)

# %%
import os
import shutil

def duplicate_directory_structure(source_directory, target_directory):
    # Iterate through all directories and subdirectories in the source directory
    for root, dirs, files in os.walk(source_directory):
        # Get the relative path of the current directory from the source directory
        relative_path = os.path.relpath(root, source_directory)
        
        # Create the corresponding directory in the target directory
        target_subdirectory = os.path.join(target_directory, relative_path)
        os.makedirs(target_subdirectory, exist_ok=True)
        
    print("Directory structure duplicated successfully.")

# Provide the path for the source directory
source_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TRAIN/"

# Provide the path for the target directory (where you want to duplicate the structure)
target_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TRAIN_GRAY_SCALE/"

# Call the function to duplicate the directory structure
duplicate_directory_structure(source_directory, target_directory)
# Out:
# Directory structure duplicated successfully.

# %%
import os
import shutil

def duplicate_directory_structure(source_directory, target_directory):
    # Iterate through all directories and subdirectories in the source directory
    for root, dirs, files in os.walk(source_directory):
        # Get the relative path of the current directory from the source directory
        relative_path = os.path.relpath(root, source_directory)
        
        # Create the corresponding directory in the target directory
        target_subdirectory = os.path.join(target_directory, relative_path)
        os.makedirs(target_subdirectory, exist_ok=True)
        
    print("Directory structure duplicated successfully.")

# Provide the path for the source directory
source_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/VALID/"

# Provide the path for the target directory (where you want to duplicate the structure)
target_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/VALID_GRAY_SCALE/"

# Call the function to duplicate the directory structure
duplicate_directory_structure(source_directory, target_directory)
# Out:
# Directory structure duplicated successfully.

# %%
import os
import shutil

def duplicate_directory_structure(source_directory, target_directory):
    # Iterate through all directories and subdirectories in the source directory
    for root, dirs, files in os.walk(source_directory):
        # Get the relative path of the current directory from the source directory
        relative_path = os.path.relpath(root, source_directory)
        
        # Create the corresponding directory in the target directory
        target_subdirectory = os.path.join(target_directory, relative_path)
        os.makedirs(target_subdirectory, exist_ok=True)
        
    print("Directory structure duplicated successfully.")

# Provide the path for the source directory
source_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TEST/"

# Provide the path for the target directory (where you want to duplicate the structure)
target_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TEST_GRAY_SCALE/"

# Call the function to duplicate the directory structure
duplicate_directory_structure(source_directory, target_directory)
# Out:
# Directory structure duplicated successfully.

# %%
import os
import cv2
import shutil

def convert_to_grayscale(image_path):
    # Read the image
    image = cv2.imread(image_path)

    # Convert the image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Expand the dimensions to match the shape (224, 224, 1)
    gray_image = gray_image[:, :, None]

    return gray_image

def stack_channels(image_path, gray_image):
    # Read the original image
    original_image = cv2.imread(image_path)

    # Stack the grayscale image channels to create a final image
    final_image = cv2.merge([gray_image, gray_image, gray_image])

    return final_image

def copy_and_convert_images(main_directory, duplicate_directory):
    # Iterate through each subclass directory in the main directory
    for subclass_dir in os.listdir(main_directory):
        subclass_dir_path = os.path.join(main_directory, subclass_dir)
        duplicate_subclass_dir_path = os.path.join(duplicate_directory, subclass_dir)
        
        # Create the corresponding subclass directory in the duplicate directory
        os.makedirs(duplicate_subclass_dir_path, exist_ok=True)
        
        # Get the list of image files in the subclass directory
        image_files = [file for file in os.listdir(subclass_dir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Iterate through each image file
        for file in image_files:
            original_file_path = os.path.join(subclass_dir_path, file)
            duplicate_file_path = os.path.join(duplicate_subclass_dir_path, file)
            
            # Convert the image to grayscale
            gray_image = convert_to_grayscale(original_file_path)
            
            # Stack the grayscale channels to create the final image
            final_image = stack_channels(original_file_path, gray_image)
            
            # Save the final image to the duplicate subclass directory
            cv2.imwrite(duplicate_file_path, final_image)

    print("Image conversion and copying completed successfully.")

# Specify the paths for the main directory and duplicate directory
main_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TRAIN/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TRAIN_GRAY_SCALE/"

# Call the function to copy and convert the images
copy_and_convert_images(main_directory, duplicate_directory)
# Out:
# Image conversion and copying completed successfully.

# %%
import os
import cv2
import shutil

def convert_to_grayscale(image_path):
    # Read the image
    image = cv2.imread(image_path)

    # Convert the image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Expand the dimensions to match the shape (224, 224, 1)
    gray_image = gray_image[:, :, None]

    return gray_image

def stack_channels(image_path, gray_image):
    # Read the original image
    original_image = cv2.imread(image_path)

    # Stack the grayscale image channels to create a final image
    final_image = cv2.merge([gray_image, gray_image, gray_image])

    return final_image

def copy_and_convert_images(main_directory, duplicate_directory):
    # Iterate through each subclass directory in the main directory
    for subclass_dir in os.listdir(main_directory):
        subclass_dir_path = os.path.join(main_directory, subclass_dir)
        duplicate_subclass_dir_path = os.path.join(duplicate_directory, subclass_dir)
        
        # Create the corresponding subclass directory in the duplicate directory
        os.makedirs(duplicate_subclass_dir_path, exist_ok=True)
        
        # Get the list of image files in the subclass directory
        image_files = [file for file in os.listdir(subclass_dir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Iterate through each image file
        for file in image_files:
            original_file_path = os.path.join(subclass_dir_path, file)
            duplicate_file_path = os.path.join(duplicate_subclass_dir_path, file)
            
            # Convert the image to grayscale
            gray_image = convert_to_grayscale(original_file_path)
            
            # Stack the grayscale channels to create the final image
            final_image = stack_channels(original_file_path, gray_image)
            
            # Save the final image to the duplicate subclass directory
            cv2.imwrite(duplicate_file_path, final_image)

    print("Image conversion and copying completed successfully.")

# Specify the paths for the main directory and duplicate directory
main_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/VALID/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/VALID_GRAY_SCALE/"

# Call the function to copy and convert the images
copy_and_convert_images(main_directory, duplicate_directory)
# Out:
# Image conversion and copying completed successfully.

# %%
import os
import cv2
import shutil

def convert_to_grayscale(image_path):
    # Read the image
    image = cv2.imread(image_path)

    # Convert the image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Expand the dimensions to match the shape (224, 224, 1)
    gray_image = gray_image[:, :, None]

    return gray_image

def stack_channels(image_path, gray_image):
    # Read the original image
    original_image = cv2.imread(image_path)

    # Stack the grayscale image channels to create a final image
    final_image = cv2.merge([gray_image, gray_image, gray_image])

    return final_image

def copy_and_convert_images(main_directory, duplicate_directory):
    # Iterate through each subclass directory in the main directory
    for subclass_dir in os.listdir(main_directory):
        subclass_dir_path = os.path.join(main_directory, subclass_dir)
        duplicate_subclass_dir_path = os.path.join(duplicate_directory, subclass_dir)
        
        # Create the corresponding subclass directory in the duplicate directory
        os.makedirs(duplicate_subclass_dir_path, exist_ok=True)
        
        # Get the list of image files in the subclass directory
        image_files = [file for file in os.listdir(subclass_dir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Iterate through each image file
        for file in image_files:
            original_file_path = os.path.join(subclass_dir_path, file)
            duplicate_file_path = os.path.join(duplicate_subclass_dir_path, file)
            
            # Convert the image to grayscale
            gray_image = convert_to_grayscale(original_file_path)
            
            # Stack the grayscale channels to create the final image
            final_image = stack_channels(original_file_path, gray_image)
            
            # Save the final image to the duplicate subclass directory
            cv2.imwrite(duplicate_file_path, final_image)

    print("Image conversion and copying completed successfully.")

# Specify the paths for the main directory and duplicate directory
main_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TEST/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TEST_GRAY_SCALE/"

# Call the function to copy and convert the images
copy_and_convert_images(main_directory, duplicate_directory)
# Out:
# Image conversion and copying completed successfully.

# %%
import shutil

directory_path = 'C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TRAIN/cycling/'  # Replace with the actual path of the directory you want to delete

# Use try-except block to handle any exceptions that may occur during the deletion process
try:
    # Remove the directory recursively
    shutil.rmtree(directory_path)
    print(f"Directory '{directory_path}' deleted successfully.")
except FileNotFoundError:
    print(f"Directory '{directory_path}' not found.")
except PermissionError:
    print(f"Permission denied: Unable to delete directory '{directory_path}'.")
except Exception as e:
    print(f"An error occurred while deleting directory '{directory_path}': {str(e)}")
# Out:
# Directory 'C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TRAIN/cycling/' deleted successfully.

# %%
import os

train_folder = 'C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_TRAIN/'  # Replace with the actual path of the "train" folder

subclass_names = [
    'calling', 'clapping', 'cycling', 'dancing', 'drinking', 'eating', 'fighting', 'hugging', 'laughing',
    'listening_to_music', 'running', 'sitting', 'sleeping', 'texting', 'using_laptop'
]

try:
    for subclass_name in subclass_names:
        subclass_path = os.path.join(train_folder, subclass_name)
        os.makedirs(subclass_path, exist_ok=True)
        print(f"Subclass folder '{subclass_name}' created successfully.")
except Exception as e:
    print(f"An error occurred while creating subclass folders: {str(e)}")
# Out:
# Subclass folder 'calling' created successfully.
# Subclass folder 'clapping' created successfully.
# Subclass folder 'cycling' created successfully.
# Subclass folder 'dancing' created successfully.
# Subclass folder 'drinking' created successfully.
# Subclass folder 'eating' created successfully.
# Subclass folder 'fighting' created successfully.
# Subclass folder 'hugging' created successfully.
# Subclass folder 'laughing' created successfully.
# Subclass folder 'listening_to_music' created successfully.
# Subclass folder 'running' created successfully.
# Subclass folder 'sitting' created successfully.
# Subclass folder 'sleeping' created successfully.
# Subclass folder 'texting' created successfully.
# Subclass folder 'using_laptop' created successfully.

# %%
import os
import shutil
import pandas as pd

main_directory = 'C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_TRAIN/'  # Replace with the actual path of the main directory
image_directory = 'C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/train/'  # Replace with the actual path of the directory containing the images
csv_file = 'C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/Training_set.csv'  # Replace with the actual path of the CSV file

# Read the CSV file using pandas
df = pd.read_csv(csv_file)

# Iterate through the images in the image directory
for filename in os.listdir(image_directory):
    image_path = os.path.join(image_directory, filename)
    
    # Check if the filename exists in the CSV file
    if filename in df['filename'].values:
        # Get the corresponding label
        label = df.loc[df['filename'] == filename, 'label'].values[0]
        
        # Create the subclass folder path within the main directory
        subclass_folder = os.path.join(main_directory, label)
        
        # Move the image to the corresponding subclass folder
        new_image_path = os.path.join(subclass_folder, filename)
        shutil.move(image_path, new_image_path)
        print(f"Image '{filename}' moved to subclass folder '{label}'.")
# Out:
# Image 'Image_1.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10.jpg' moved to subclass folder 'dancing'.
# Image 'Image_100.jpg' moved to subclass folder 'fighting'.
# Image 'Image_1000.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10000.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10001.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10002.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10003.jpg' moved to subclass folder 'texting'.
# Image 'Image_10004.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10005.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10006.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10007.jpg' moved to subclass folder 'eating'.
# Image 'Image_10008.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10009.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_1001.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10010.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10011.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10012.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10013.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10014.jpg' moved to subclass folder 'texting'.
# Image 'Image_10015.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10016.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10017.jpg' moved to subclass folder 'running'.
# Image 'Image_10018.jpg' moved to subclass folder 'eating'.
# Image 'Image_10019.jpg' moved to subclass folder 'calling'.
# Image 'Image_1002.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10020.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10021.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10022.jpg' moved to subclass folder 'calling'.
# Image 'Image_10023.jpg' moved to subclass folder 'calling'.
# Image 'Image_10024.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10025.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10026.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10027.jpg' moved to subclass folder 'calling'.
# Image 'Image_10028.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10029.jpg' moved to subclass folder 'clapping'.
# Image 'Image_1003.jpg' moved to subclass folder 'calling'.
# Image 'Image_10030.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10031.jpg' moved to subclass folder 'eating'.
# Image 'Image_10032.jpg' moved to subclass folder 'running'.
# Image 'Image_10033.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10034.jpg' moved to subclass folder 'calling'.
# Image 'Image_10035.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10036.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10037.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10038.jpg' moved to subclass folder 'running'.
# Image 'Image_10039.jpg' moved to subclass folder 'clapping'.
# Image 'Image_1004.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10040.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10041.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10042.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10043.jpg' moved to subclass folder 'texting'.
# Image 'Image_10044.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10045.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10046.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10047.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10048.jpg' moved to subclass folder 'eating'.
# Image 'Image_10049.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_1005.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10050.jpg' moved to subclass folder 'running'.
# Image 'Image_10051.jpg' moved to subclass folder 'calling'.
# Image 'Image_10052.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10053.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10054.jpg' moved to subclass folder 'running'.
# Image 'Image_10055.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10056.jpg' moved to subclass folder 'eating'.
# Image 'Image_10057.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10058.jpg' moved to subclass folder 'running'.
# Image 'Image_10059.jpg' moved to subclass folder 'calling'.
# Image 'Image_1006.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10060.jpg' moved to subclass folder 'running'.
# Image 'Image_10061.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10062.jpg' moved to subclass folder 'texting'.
# Image 'Image_10063.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10064.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10065.jpg' moved to subclass folder 'eating'.
# Image 'Image_10066.jpg' moved to subclass folder 'texting'.
# Image 'Image_10067.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10068.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10069.jpg' moved to subclass folder 'dancing'.
# Image 'Image_1007.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10070.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10071.jpg' moved to subclass folder 'texting'.
# Image 'Image_10072.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10073.jpg' moved to subclass folder 'texting'.
# Image 'Image_10074.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10075.jpg' moved to subclass folder 'texting'.
# Image 'Image_10076.jpg' moved to subclass folder 'texting'.
# Image 'Image_10077.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10078.jpg' moved to subclass folder 'eating'.
# Image 'Image_10079.jpg' moved to subclass folder 'hugging'.
# Image 'Image_1008.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10080.jpg' moved to subclass folder 'texting'.
# Image 'Image_10081.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10082.jpg' moved to subclass folder 'calling'.
# Image 'Image_10083.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10084.jpg' moved to subclass folder 'calling'.
# Image 'Image_10085.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10086.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10087.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10088.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10089.jpg' moved to subclass folder 'clapping'.
# Image 'Image_1009.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10090.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10091.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10092.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10093.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10094.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10095.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10096.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10097.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10098.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10099.jpg' moved to subclass folder 'cycling'.
# Image 'Image_101.jpg' moved to subclass folder 'hugging'.
# Image 'Image_1010.jpg' moved to subclass folder 'texting'.
# Image 'Image_10100.jpg' moved to subclass folder 'running'.
# Image 'Image_10101.jpg' moved to subclass folder 'texting'.
# Image 'Image_10102.jpg' moved to subclass folder 'texting'.
# Image 'Image_10103.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10104.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10105.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10106.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10107.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10108.jpg' moved to subclass folder 'running'.
# Image 'Image_10109.jpg' moved to subclass folder 'hugging'.
# Image 'Image_1011.jpg' moved to subclass folder 'eating'.
# Image 'Image_10110.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10111.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10112.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10113.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10114.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10115.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10116.jpg' moved to subclass folder 'running'.
# Image 'Image_10117.jpg' moved to subclass folder 'running'.
# Image 'Image_10118.jpg' moved to subclass folder 'eating'.
# Image 'Image_10119.jpg' moved to subclass folder 'hugging'.
# Image 'Image_1012.jpg' moved to subclass folder 'running'.
# Image 'Image_10120.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10121.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10122.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10123.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10124.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10125.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10126.jpg' moved to subclass folder 'running'.
# Image 'Image_10127.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10128.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10129.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_1013.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10130.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10131.jpg' moved to subclass folder 'eating'.
# Image 'Image_10132.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10133.jpg' moved to subclass folder 'texting'.
# Image 'Image_10134.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10135.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10136.jpg' moved to subclass folder 'texting'.
# Image 'Image_10137.jpg' moved to subclass folder 'calling'.
# Image 'Image_10138.jpg' moved to subclass folder 'texting'.
# Image 'Image_10139.jpg' moved to subclass folder 'hugging'.
# Image 'Image_1014.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10140.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10141.jpg' moved to subclass folder 'calling'.
# Image 'Image_10142.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10143.jpg' moved to subclass folder 'calling'.
# Image 'Image_10144.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10145.jpg' moved to subclass folder 'texting'.
# Image 'Image_10146.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10147.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10148.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10149.jpg' moved to subclass folder 'laughing'.
# Image 'Image_1015.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10150.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10151.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10152.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10153.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10154.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10155.jpg' moved to subclass folder 'texting'.
# Image 'Image_10156.jpg' moved to subclass folder 'eating'.
# Image 'Image_10157.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10158.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10159.jpg' moved to subclass folder 'hugging'.
# Image 'Image_1016.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10160.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10161.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10162.jpg' moved to subclass folder 'texting'.
# Image 'Image_10163.jpg' moved to subclass folder 'calling'.
# Image 'Image_10164.jpg' moved to subclass folder 'calling'.
# Image 'Image_10165.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10166.jpg' moved to subclass folder 'calling'.
# Image 'Image_10167.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10168.jpg' moved to subclass folder 'texting'.
# Image 'Image_10169.jpg' moved to subclass folder 'sitting'.
# Image 'Image_1017.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10170.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10171.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10172.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10173.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10174.jpg' moved to subclass folder 'eating'.
# Image 'Image_10175.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10176.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10177.jpg' moved to subclass folder 'texting'.
# Image 'Image_10178.jpg' moved to subclass folder 'texting'.
# Image 'Image_10179.jpg' moved to subclass folder 'dancing'.
# Image 'Image_1018.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10180.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10181.jpg' moved to subclass folder 'texting'.
# Image 'Image_10182.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10183.jpg' moved to subclass folder 'running'.
# Image 'Image_10184.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10185.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10186.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10187.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10188.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10189.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_1019.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10190.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10191.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10192.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10193.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10194.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10195.jpg' moved to subclass folder 'running'.
# Image 'Image_10196.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10197.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10198.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10199.jpg' moved to subclass folder 'sitting'.
# Image 'Image_102.jpg' moved to subclass folder 'texting'.
# Image 'Image_1020.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10200.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10201.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10202.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10203.jpg' moved to subclass folder 'calling'.
# Image 'Image_10204.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10205.jpg' moved to subclass folder 'eating'.
# Image 'Image_10206.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10207.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10208.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10209.jpg' moved to subclass folder 'eating'.
# Image 'Image_1021.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10210.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10211.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10212.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10213.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10214.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10215.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10216.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10217.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10218.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10219.jpg' moved to subclass folder 'clapping'.
# Image 'Image_1022.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10220.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10221.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10222.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10223.jpg' moved to subclass folder 'eating'.
# Image 'Image_10224.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10225.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10226.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10227.jpg' moved to subclass folder 'calling'.
# Image 'Image_10228.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10229.jpg' moved to subclass folder 'hugging'.
# Image 'Image_1023.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10230.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10231.jpg' moved to subclass folder 'calling'.
# Image 'Image_10232.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10233.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10234.jpg' moved to subclass folder 'texting'.
# Image 'Image_10235.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10236.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10237.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10238.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10239.jpg' moved to subclass folder 'drinking'.
# Image 'Image_1024.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10240.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10241.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10242.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10243.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10244.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10245.jpg' moved to subclass folder 'calling'.
# Image 'Image_10246.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10247.jpg' moved to subclass folder 'eating'.
# Image 'Image_10248.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10249.jpg' moved to subclass folder 'fighting'.
# Image 'Image_1025.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10250.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10251.jpg' moved to subclass folder 'running'.
# Image 'Image_10252.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10253.jpg' moved to subclass folder 'texting'.
# Image 'Image_10254.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10255.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10256.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10257.jpg' moved to subclass folder 'calling'.
# Image 'Image_10258.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10259.jpg' moved to subclass folder 'sitting'.
# Image 'Image_1026.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10260.jpg' moved to subclass folder 'calling'.
# Image 'Image_10261.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10262.jpg' moved to subclass folder 'texting'.
# Image 'Image_10263.jpg' moved to subclass folder 'calling'.
# Image 'Image_10264.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10265.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10266.jpg' moved to subclass folder 'texting'.
# Image 'Image_10267.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10268.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10269.jpg' moved to subclass folder 'running'.
# Image 'Image_1027.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10270.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10271.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10272.jpg' moved to subclass folder 'calling'.
# Image 'Image_10273.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10274.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10275.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10276.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10277.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10278.jpg' moved to subclass folder 'running'.
# Image 'Image_10279.jpg' moved to subclass folder 'drinking'.
# Image 'Image_1028.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10280.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10281.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10282.jpg' moved to subclass folder 'running'.
# Image 'Image_10283.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10284.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10285.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10286.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10287.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10288.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10289.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_1029.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10290.jpg' moved to subclass folder 'calling'.
# Image 'Image_10291.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10292.jpg' moved to subclass folder 'texting'.
# Image 'Image_10293.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10294.jpg' moved to subclass folder 'calling'.
# Image 'Image_10295.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10296.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10297.jpg' moved to subclass folder 'running'.
# Image 'Image_10298.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10299.jpg' moved to subclass folder 'dancing'.
# Image 'Image_103.jpg' moved to subclass folder 'texting'.
# Image 'Image_1030.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10300.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10301.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10302.jpg' moved to subclass folder 'eating'.
# Image 'Image_10303.jpg' moved to subclass folder 'eating'.
# Image 'Image_10304.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10305.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10306.jpg' moved to subclass folder 'texting'.
# Image 'Image_10307.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10308.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10309.jpg' moved to subclass folder 'cycling'.
# Image 'Image_1031.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10310.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10311.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10312.jpg' moved to subclass folder 'calling'.
# Image 'Image_10313.jpg' moved to subclass folder 'calling'.
# Image 'Image_10314.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10315.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10316.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10317.jpg' moved to subclass folder 'texting'.
# Image 'Image_10318.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10319.jpg' moved to subclass folder 'hugging'.
# Image 'Image_1032.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10320.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10321.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10322.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10323.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10324.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10325.jpg' moved to subclass folder 'eating'.
# Image 'Image_10326.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10327.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10328.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10329.jpg' moved to subclass folder 'drinking'.
# Image 'Image_1033.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10330.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10331.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10332.jpg' moved to subclass folder 'calling'.
# Image 'Image_10333.jpg' moved to subclass folder 'calling'.
# Image 'Image_10334.jpg' moved to subclass folder 'texting'.
# Image 'Image_10335.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10336.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10337.jpg' moved to subclass folder 'eating'.
# Image 'Image_10338.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10339.jpg' moved to subclass folder 'running'.
# Image 'Image_1034.jpg' moved to subclass folder 'running'.
# Image 'Image_10340.jpg' moved to subclass folder 'calling'.
# Image 'Image_10341.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10342.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10343.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10344.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10345.jpg' moved to subclass folder 'eating'.
# Image 'Image_10346.jpg' moved to subclass folder 'running'.
# Image 'Image_10347.jpg' moved to subclass folder 'texting'.
# Image 'Image_10348.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10349.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_1035.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10350.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10351.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10352.jpg' moved to subclass folder 'eating'.
# Image 'Image_10353.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10354.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10355.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10356.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10357.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10358.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10359.jpg' moved to subclass folder 'cycling'.
# Image 'Image_1036.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10360.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10361.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10362.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10363.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10364.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10365.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10366.jpg' moved to subclass folder 'texting'.
# Image 'Image_10367.jpg' moved to subclass folder 'texting'.
# Image 'Image_10368.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10369.jpg' moved to subclass folder 'eating'.
# Image 'Image_1037.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10370.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10371.jpg' moved to subclass folder 'texting'.
# Image 'Image_10372.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10373.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10374.jpg' moved to subclass folder 'running'.
# Image 'Image_10375.jpg' moved to subclass folder 'running'.
# Image 'Image_10376.jpg' moved to subclass folder 'running'.
# Image 'Image_10377.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10378.jpg' moved to subclass folder 'running'.
# Image 'Image_10379.jpg' moved to subclass folder 'clapping'.
# Image 'Image_1038.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10380.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10381.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10382.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10383.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10384.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10385.jpg' moved to subclass folder 'texting'.
# Image 'Image_10386.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10387.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10388.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10389.jpg' moved to subclass folder 'eating'.
# Image 'Image_1039.jpg' moved to subclass folder 'running'.
# Image 'Image_10390.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10391.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10392.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10393.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10394.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10395.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10396.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10397.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10398.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10399.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_104.jpg' moved to subclass folder 'texting'.
# Image 'Image_1040.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10400.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10401.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10402.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10403.jpg' moved to subclass folder 'texting'.
# Image 'Image_10404.jpg' moved to subclass folder 'texting'.
# Image 'Image_10405.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10406.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10407.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10408.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10409.jpg' moved to subclass folder 'dancing'.
# Image 'Image_1041.jpg' moved to subclass folder 'texting'.
# Image 'Image_10410.jpg' moved to subclass folder 'eating'.
# Image 'Image_10411.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10412.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10413.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10414.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10415.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10416.jpg' moved to subclass folder 'texting'.
# Image 'Image_10417.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10418.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10419.jpg' moved to subclass folder 'eating'.
# Image 'Image_1042.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10420.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10421.jpg' moved to subclass folder 'eating'.
# Image 'Image_10422.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10423.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10424.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10425.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10426.jpg' moved to subclass folder 'eating'.
# Image 'Image_10427.jpg' moved to subclass folder 'texting'.
# Image 'Image_10428.jpg' moved to subclass folder 'texting'.
# Image 'Image_10429.jpg' moved to subclass folder 'texting'.
# Image 'Image_1043.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10430.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10431.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10432.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10433.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10434.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10435.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10436.jpg' moved to subclass folder 'eating'.
# Image 'Image_10437.jpg' moved to subclass folder 'running'.
# Image 'Image_10438.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10439.jpg' moved to subclass folder 'clapping'.
# Image 'Image_1044.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10440.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10441.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10442.jpg' moved to subclass folder 'texting'.
# Image 'Image_10443.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10444.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10445.jpg' moved to subclass folder 'calling'.
# Image 'Image_10446.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10447.jpg' moved to subclass folder 'calling'.
# Image 'Image_10448.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10449.jpg' moved to subclass folder 'dancing'.
# Image 'Image_1045.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10450.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10451.jpg' moved to subclass folder 'eating'.
# Image 'Image_10452.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10453.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10454.jpg' moved to subclass folder 'eating'.
# Image 'Image_10455.jpg' moved to subclass folder 'texting'.
# Image 'Image_10456.jpg' moved to subclass folder 'calling'.
# Image 'Image_10457.jpg' moved to subclass folder 'texting'.
# Image 'Image_10458.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10459.jpg' moved to subclass folder 'cycling'.
# Image 'Image_1046.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10460.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10461.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10462.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10463.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10464.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10465.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10466.jpg' moved to subclass folder 'running'.
# Image 'Image_10467.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10468.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10469.jpg' moved to subclass folder 'dancing'.
# Image 'Image_1047.jpg' moved to subclass folder 'eating'.
# Image 'Image_10470.jpg' moved to subclass folder 'texting'.
# Image 'Image_10471.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10472.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10473.jpg' moved to subclass folder 'eating'.
# Image 'Image_10474.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10475.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10476.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10477.jpg' moved to subclass folder 'texting'.
# Image 'Image_10478.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10479.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_1048.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10480.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10481.jpg' moved to subclass folder 'calling'.
# Image 'Image_10482.jpg' moved to subclass folder 'running'.
# Image 'Image_10483.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10484.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10485.jpg' moved to subclass folder 'texting'.
# Image 'Image_10486.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10487.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10488.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10489.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_1049.jpg' moved to subclass folder 'texting'.
# Image 'Image_10490.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10491.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10492.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10493.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10494.jpg' moved to subclass folder 'texting'.
# Image 'Image_10495.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10496.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10497.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10498.jpg' moved to subclass folder 'eating'.
# Image 'Image_10499.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_105.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_1050.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10500.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10501.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10502.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10503.jpg' moved to subclass folder 'running'.
# Image 'Image_10504.jpg' moved to subclass folder 'calling'.
# Image 'Image_10505.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10506.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10507.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10508.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10509.jpg' moved to subclass folder 'drinking'.
# Image 'Image_1051.jpg' moved to subclass folder 'calling'.
# Image 'Image_10510.jpg' moved to subclass folder 'eating'.
# Image 'Image_10511.jpg' moved to subclass folder 'eating'.
# Image 'Image_10512.jpg' moved to subclass folder 'running'.
# Image 'Image_10513.jpg' moved to subclass folder 'texting'.
# Image 'Image_10514.jpg' moved to subclass folder 'running'.
# Image 'Image_10515.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10516.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10517.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10518.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10519.jpg' moved to subclass folder 'clapping'.
# Image 'Image_1052.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10520.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10521.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10522.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10523.jpg' moved to subclass folder 'calling'.
# Image 'Image_10524.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10525.jpg' moved to subclass folder 'eating'.
# Image 'Image_10526.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10527.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10528.jpg' moved to subclass folder 'calling'.
# Image 'Image_10529.jpg' moved to subclass folder 'sitting'.
# Image 'Image_1053.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10530.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10531.jpg' moved to subclass folder 'eating'.
# Image 'Image_10532.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10533.jpg' moved to subclass folder 'running'.
# Image 'Image_10534.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10535.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10536.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10537.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10538.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10539.jpg' moved to subclass folder 'texting'.
# Image 'Image_1054.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10540.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10541.jpg' moved to subclass folder 'texting'.
# Image 'Image_10542.jpg' moved to subclass folder 'running'.
# Image 'Image_10543.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10544.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10545.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10546.jpg' moved to subclass folder 'running'.
# Image 'Image_10547.jpg' moved to subclass folder 'running'.
# Image 'Image_10548.jpg' moved to subclass folder 'texting'.
# Image 'Image_10549.jpg' moved to subclass folder 'laughing'.
# Image 'Image_1055.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10550.jpg' moved to subclass folder 'eating'.
# Image 'Image_10551.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10552.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10553.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10554.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10555.jpg' moved to subclass folder 'calling'.
# Image 'Image_10556.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10557.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10558.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10559.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_1056.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10560.jpg' moved to subclass folder 'calling'.
# Image 'Image_10561.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10562.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10563.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10564.jpg' moved to subclass folder 'running'.
# Image 'Image_10565.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10566.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10567.jpg' moved to subclass folder 'eating'.
# Image 'Image_10568.jpg' moved to subclass folder 'running'.
# Image 'Image_10569.jpg' moved to subclass folder 'drinking'.
# Image 'Image_1057.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10570.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10571.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10572.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10573.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10574.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10575.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10576.jpg' moved to subclass folder 'texting'.
# Image 'Image_10577.jpg' moved to subclass folder 'eating'.
# Image 'Image_10578.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10579.jpg' moved to subclass folder 'eating'.
# Image 'Image_1058.jpg' moved to subclass folder 'calling'.
# Image 'Image_10580.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10581.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10582.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10583.jpg' moved to subclass folder 'calling'.
# Image 'Image_10584.jpg' moved to subclass folder 'texting'.
# Image 'Image_10585.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10586.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10587.jpg' moved to subclass folder 'eating'.
# Image 'Image_10588.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10589.jpg' moved to subclass folder 'fighting'.
# Image 'Image_1059.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10590.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10591.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10592.jpg' moved to subclass folder 'texting'.
# Image 'Image_10593.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10594.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10595.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10596.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10597.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10598.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10599.jpg' moved to subclass folder 'laughing'.
# Image 'Image_106.jpg' moved to subclass folder 'drinking'.
# Image 'Image_1060.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10600.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10601.jpg' moved to subclass folder 'eating'.
# Image 'Image_10602.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10603.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10604.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10605.jpg' moved to subclass folder 'texting'.
# Image 'Image_10606.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10607.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10608.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10609.jpg' moved to subclass folder 'laughing'.
# Image 'Image_1061.jpg' moved to subclass folder 'running'.
# Image 'Image_10610.jpg' moved to subclass folder 'eating'.
# Image 'Image_10611.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10612.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10613.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10614.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10615.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10616.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10617.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10618.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10619.jpg' moved to subclass folder 'dancing'.
# Image 'Image_1062.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10620.jpg' moved to subclass folder 'running'.
# Image 'Image_10621.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10622.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10623.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10624.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10625.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10626.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10627.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10628.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10629.jpg' moved to subclass folder 'texting'.
# Image 'Image_1063.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10630.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10631.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10632.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10633.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10634.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10635.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10636.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10637.jpg' moved to subclass folder 'texting'.
# Image 'Image_10638.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10639.jpg' moved to subclass folder 'clapping'.
# Image 'Image_1064.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10640.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10641.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10642.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10643.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10644.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10645.jpg' moved to subclass folder 'eating'.
# Image 'Image_10646.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10647.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10648.jpg' moved to subclass folder 'running'.
# Image 'Image_10649.jpg' moved to subclass folder 'eating'.
# Image 'Image_1065.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10650.jpg' moved to subclass folder 'eating'.
# Image 'Image_10651.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10652.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10653.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10654.jpg' moved to subclass folder 'eating'.
# Image 'Image_10655.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10656.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10657.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10658.jpg' moved to subclass folder 'texting'.
# Image 'Image_10659.jpg' moved to subclass folder 'eating'.
# Image 'Image_1066.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10660.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10661.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10662.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10663.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10664.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10665.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10666.jpg' moved to subclass folder 'calling'.
# Image 'Image_10667.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10668.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10669.jpg' moved to subclass folder 'fighting'.
# Image 'Image_1067.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10670.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10671.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10672.jpg' moved to subclass folder 'texting'.
# Image 'Image_10673.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_10674.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10675.jpg' moved to subclass folder 'running'.
# Image 'Image_10676.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_10677.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10678.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10679.jpg' moved to subclass folder 'eating'.
# Image 'Image_1068.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10680.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10681.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10682.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10683.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10684.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10685.jpg' moved to subclass folder 'dancing'.
# Image 'Image_10686.jpg' moved to subclass folder 'laughing'.
# Image 'Image_10687.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10688.jpg' moved to subclass folder 'texting'.
# Image 'Image_10689.jpg' moved to subclass folder 'sitting'.
# Image 'Image_1069.jpg' moved to subclass folder 'hugging'.
# Image 'Image_10690.jpg' moved to subclass folder 'eating'.
# Image 'Image_10691.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10692.jpg' moved to subclass folder 'eating'.
# Image 'Image_10693.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10694.jpg' moved to subclass folder 'fighting'.
# Image 'Image_10695.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_10696.jpg' moved to subclass folder 'sitting'.
# Image 'Image_10697.jpg' moved to subclass folder 'clapping'.
# Image 'Image_10698.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10699.jpg' moved to subclass folder 'running'.
# Image 'Image_107.jpg' moved to subclass folder 'running'.
# Image 'Image_1070.jpg' moved to subclass folder 'cycling'.
# Image 'Image_10700.jpg' moved to subclass folder 'drinking'.
# Image 'Image_10701.jpg' moved to subclass folder 'clapping'.
# ...
# Image 'Image_9760.jpg' moved to subclass folder 'dancing'.
# Image 'Image_9761.jpg' moved to subclass folder 'eating'.
# Image 'Image_9762.jpg' moved to subclass folder 'eating'.
# Image 'Image_9763.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9764.jpg' moved to subclass folder 'clapping'.
# Image 'Image_9765.jpg' moved to subclass folder 'cycling'.
# Image 'Image_9766.jpg' moved to subclass folder 'laughing'.
# Image 'Image_9767.jpg' moved to subclass folder 'calling'.
# Image 'Image_9768.jpg' moved to subclass folder 'running'.
# Image 'Image_9769.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_977.jpg' moved to subclass folder 'texting'.
# Image 'Image_9770.jpg' moved to subclass folder 'running'.
# Image 'Image_9771.jpg' moved to subclass folder 'eating'.
# Image 'Image_9772.jpg' moved to subclass folder 'calling'.
# Image 'Image_9773.jpg' moved to subclass folder 'running'.
# Image 'Image_9774.jpg' moved to subclass folder 'eating'.
# Image 'Image_9775.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9776.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_9777.jpg' moved to subclass folder 'dancing'.
# Image 'Image_9778.jpg' moved to subclass folder 'calling'.
# Image 'Image_9779.jpg' moved to subclass folder 'texting'.
# Image 'Image_978.jpg' moved to subclass folder 'sitting'.
# Image 'Image_9780.jpg' moved to subclass folder 'sitting'.
# Image 'Image_9781.jpg' moved to subclass folder 'cycling'.
# Image 'Image_9782.jpg' moved to subclass folder 'sitting'.
# Image 'Image_9783.jpg' moved to subclass folder 'clapping'.
# Image 'Image_9784.jpg' moved to subclass folder 'sitting'.
# Image 'Image_9785.jpg' moved to subclass folder 'drinking'.
# Image 'Image_9786.jpg' moved to subclass folder 'drinking'.
# Image 'Image_9787.jpg' moved to subclass folder 'texting'.
# Image 'Image_9788.jpg' moved to subclass folder 'sitting'.
# Image 'Image_9789.jpg' moved to subclass folder 'drinking'.
# Image 'Image_979.jpg' moved to subclass folder 'sitting'.
# Image 'Image_9790.jpg' moved to subclass folder 'calling'.
# Image 'Image_9791.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9792.jpg' moved to subclass folder 'laughing'.
# Image 'Image_9793.jpg' moved to subclass folder 'dancing'.
# Image 'Image_9794.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_9795.jpg' moved to subclass folder 'texting'.
# Image 'Image_9796.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9797.jpg' moved to subclass folder 'texting'.
# Image 'Image_9798.jpg' moved to subclass folder 'running'.
# Image 'Image_9799.jpg' moved to subclass folder 'eating'.
# Image 'Image_98.jpg' moved to subclass folder 'drinking'.
# Image 'Image_980.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_9800.jpg' moved to subclass folder 'clapping'.
# Image 'Image_9801.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9802.jpg' moved to subclass folder 'running'.
# Image 'Image_9803.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9804.jpg' moved to subclass folder 'clapping'.
# Image 'Image_9805.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9806.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9807.jpg' moved to subclass folder 'laughing'.
# Image 'Image_9808.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_9809.jpg' moved to subclass folder 'dancing'.
# Image 'Image_981.jpg' moved to subclass folder 'texting'.
# Image 'Image_9810.jpg' moved to subclass folder 'calling'.
# Image 'Image_9811.jpg' moved to subclass folder 'hugging'.
# Image 'Image_9812.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_9813.jpg' moved to subclass folder 'eating'.
# Image 'Image_9814.jpg' moved to subclass folder 'clapping'.
# Image 'Image_9815.jpg' moved to subclass folder 'clapping'.
# Image 'Image_9816.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9817.jpg' moved to subclass folder 'hugging'.
# Image 'Image_9818.jpg' moved to subclass folder 'calling'.
# Image 'Image_9819.jpg' moved to subclass folder 'texting'.
# Image 'Image_982.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9820.jpg' moved to subclass folder 'dancing'.
# Image 'Image_9821.jpg' moved to subclass folder 'clapping'.
# Image 'Image_9822.jpg' moved to subclass folder 'laughing'.
# Image 'Image_9823.jpg' moved to subclass folder 'eating'.
# Image 'Image_9824.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9825.jpg' moved to subclass folder 'cycling'.
# Image 'Image_9826.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9827.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9828.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9829.jpg' moved to subclass folder 'eating'.
# Image 'Image_983.jpg' moved to subclass folder 'calling'.
# Image 'Image_9830.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9831.jpg' moved to subclass folder 'dancing'.
# Image 'Image_9832.jpg' moved to subclass folder 'clapping'.
# Image 'Image_9833.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9834.jpg' moved to subclass folder 'laughing'.
# Image 'Image_9835.jpg' moved to subclass folder 'dancing'.
# Image 'Image_9836.jpg' moved to subclass folder 'texting'.
# Image 'Image_9837.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9838.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9839.jpg' moved to subclass folder 'calling'.
# Image 'Image_984.jpg' moved to subclass folder 'calling'.
# Image 'Image_9840.jpg' moved to subclass folder 'running'.
# Image 'Image_9841.jpg' moved to subclass folder 'cycling'.
# Image 'Image_9842.jpg' moved to subclass folder 'hugging'.
# Image 'Image_9843.jpg' moved to subclass folder 'drinking'.
# Image 'Image_9844.jpg' moved to subclass folder 'clapping'.
# Image 'Image_9845.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9846.jpg' moved to subclass folder 'dancing'.
# Image 'Image_9847.jpg' moved to subclass folder 'clapping'.
# Image 'Image_9848.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9849.jpg' moved to subclass folder 'running'.
# Image 'Image_985.jpg' moved to subclass folder 'eating'.
# Image 'Image_9850.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9851.jpg' moved to subclass folder 'laughing'.
# Image 'Image_9852.jpg' moved to subclass folder 'dancing'.
# Image 'Image_9853.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9854.jpg' moved to subclass folder 'hugging'.
# Image 'Image_9855.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9856.jpg' moved to subclass folder 'texting'.
# Image 'Image_9857.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9858.jpg' moved to subclass folder 'cycling'.
# Image 'Image_9859.jpg' moved to subclass folder 'hugging'.
# Image 'Image_986.jpg' moved to subclass folder 'eating'.
# Image 'Image_9860.jpg' moved to subclass folder 'running'.
# Image 'Image_9861.jpg' moved to subclass folder 'sitting'.
# Image 'Image_9862.jpg' moved to subclass folder 'hugging'.
# Image 'Image_9863.jpg' moved to subclass folder 'cycling'.
# Image 'Image_9864.jpg' moved to subclass folder 'clapping'.
# Image 'Image_9865.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9866.jpg' moved to subclass folder 'calling'.
# Image 'Image_9867.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_9868.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9869.jpg' moved to subclass folder 'drinking'.
# Image 'Image_987.jpg' moved to subclass folder 'running'.
# Image 'Image_9870.jpg' moved to subclass folder 'dancing'.
# Image 'Image_9871.jpg' moved to subclass folder 'dancing'.
# Image 'Image_9872.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9873.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_9874.jpg' moved to subclass folder 'clapping'.
# Image 'Image_9875.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9876.jpg' moved to subclass folder 'cycling'.
# Image 'Image_9877.jpg' moved to subclass folder 'texting'.
# Image 'Image_9878.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9879.jpg' moved to subclass folder 'drinking'.
# Image 'Image_988.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9880.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9881.jpg' moved to subclass folder 'texting'.
# Image 'Image_9882.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9883.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9884.jpg' moved to subclass folder 'eating'.
# Image 'Image_9885.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9886.jpg' moved to subclass folder 'clapping'.
# Image 'Image_9887.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9888.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_9889.jpg' moved to subclass folder 'sitting'.
# Image 'Image_989.jpg' moved to subclass folder 'drinking'.
# Image 'Image_9890.jpg' moved to subclass folder 'eating'.
# Image 'Image_9891.jpg' moved to subclass folder 'drinking'.
# Image 'Image_9892.jpg' moved to subclass folder 'eating'.
# Image 'Image_9893.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9894.jpg' moved to subclass folder 'eating'.
# Image 'Image_9895.jpg' moved to subclass folder 'texting'.
# Image 'Image_9896.jpg' moved to subclass folder 'cycling'.
# Image 'Image_9897.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9898.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9899.jpg' moved to subclass folder 'cycling'.
# Image 'Image_99.jpg' moved to subclass folder 'texting'.
# Image 'Image_990.jpg' moved to subclass folder 'hugging'.
# Image 'Image_9900.jpg' moved to subclass folder 'drinking'.
# Image 'Image_9901.jpg' moved to subclass folder 'clapping'.
# Image 'Image_9902.jpg' moved to subclass folder 'clapping'.
# Image 'Image_9903.jpg' moved to subclass folder 'sitting'.
# Image 'Image_9904.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9905.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9906.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_9907.jpg' moved to subclass folder 'laughing'.
# Image 'Image_9908.jpg' moved to subclass folder 'hugging'.
# Image 'Image_9909.jpg' moved to subclass folder 'texting'.
# Image 'Image_991.jpg' moved to subclass folder 'texting'.
# Image 'Image_9910.jpg' moved to subclass folder 'calling'.
# Image 'Image_9911.jpg' moved to subclass folder 'calling'.
# Image 'Image_9912.jpg' moved to subclass folder 'running'.
# Image 'Image_9913.jpg' moved to subclass folder 'calling'.
# Image 'Image_9914.jpg' moved to subclass folder 'sitting'.
# Image 'Image_9915.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_9916.jpg' moved to subclass folder 'texting'.
# Image 'Image_9917.jpg' moved to subclass folder 'hugging'.
# Image 'Image_9918.jpg' moved to subclass folder 'texting'.
# Image 'Image_9919.jpg' moved to subclass folder 'cycling'.
# Image 'Image_992.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_9920.jpg' moved to subclass folder 'dancing'.
# Image 'Image_9921.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9922.jpg' moved to subclass folder 'cycling'.
# Image 'Image_9923.jpg' moved to subclass folder 'calling'.
# Image 'Image_9924.jpg' moved to subclass folder 'drinking'.
# Image 'Image_9925.jpg' moved to subclass folder 'running'.
# Image 'Image_9926.jpg' moved to subclass folder 'cycling'.
# Image 'Image_9927.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9928.jpg' moved to subclass folder 'running'.
# Image 'Image_9929.jpg' moved to subclass folder 'laughing'.
# Image 'Image_993.jpg' moved to subclass folder 'laughing'.
# Image 'Image_9930.jpg' moved to subclass folder 'sitting'.
# Image 'Image_9931.jpg' moved to subclass folder 'eating'.
# Image 'Image_9932.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9933.jpg' moved to subclass folder 'eating'.
# Image 'Image_9934.jpg' moved to subclass folder 'dancing'.
# Image 'Image_9935.jpg' moved to subclass folder 'hugging'.
# Image 'Image_9936.jpg' moved to subclass folder 'calling'.
# Image 'Image_9937.jpg' moved to subclass folder 'cycling'.
# Image 'Image_9938.jpg' moved to subclass folder 'cycling'.
# Image 'Image_9939.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_994.jpg' moved to subclass folder 'texting'.
# Image 'Image_9940.jpg' moved to subclass folder 'eating'.
# Image 'Image_9941.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9942.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9943.jpg' moved to subclass folder 'hugging'.
# Image 'Image_9944.jpg' moved to subclass folder 'sitting'.
# Image 'Image_9945.jpg' moved to subclass folder 'running'.
# Image 'Image_9946.jpg' moved to subclass folder 'dancing'.
# Image 'Image_9947.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9948.jpg' moved to subclass folder 'texting'.
# Image 'Image_9949.jpg' moved to subclass folder 'cycling'.
# Image 'Image_995.jpg' moved to subclass folder 'drinking'.
# Image 'Image_9950.jpg' moved to subclass folder 'clapping'.
# Image 'Image_9951.jpg' moved to subclass folder 'running'.
# Image 'Image_9952.jpg' moved to subclass folder 'calling'.
# Image 'Image_9953.jpg' moved to subclass folder 'laughing'.
# Image 'Image_9954.jpg' moved to subclass folder 'hugging'.
# Image 'Image_9955.jpg' moved to subclass folder 'drinking'.
# Image 'Image_9956.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9957.jpg' moved to subclass folder 'laughing'.
# Image 'Image_9958.jpg' moved to subclass folder 'laughing'.
# Image 'Image_9959.jpg' moved to subclass folder 'fighting'.
# Image 'Image_996.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_9960.jpg' moved to subclass folder 'cycling'.
# Image 'Image_9961.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_9962.jpg' moved to subclass folder 'drinking'.
# Image 'Image_9963.jpg' moved to subclass folder 'texting'.
# Image 'Image_9964.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9965.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9966.jpg' moved to subclass folder 'texting'.
# Image 'Image_9967.jpg' moved to subclass folder 'running'.
# Image 'Image_9968.jpg' moved to subclass folder 'sitting'.
# Image 'Image_9969.jpg' moved to subclass folder 'laughing'.
# Image 'Image_997.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9970.jpg' moved to subclass folder 'sitting'.
# Image 'Image_9971.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9972.jpg' moved to subclass folder 'hugging'.
# Image 'Image_9973.jpg' moved to subclass folder 'fighting'.
# Image 'Image_9974.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9975.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9976.jpg' moved to subclass folder 'dancing'.
# Image 'Image_9977.jpg' moved to subclass folder 'calling'.
# Image 'Image_9978.jpg' moved to subclass folder 'texting'.
# Image 'Image_9979.jpg' moved to subclass folder 'eating'.
# Image 'Image_998.jpg' moved to subclass folder 'texting'.
# Image 'Image_9980.jpg' moved to subclass folder 'hugging'.
# Image 'Image_9981.jpg' moved to subclass folder 'drinking'.
# Image 'Image_9982.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9983.jpg' moved to subclass folder 'listening_to_music'.
# Image 'Image_9984.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9985.jpg' moved to subclass folder 'dancing'.
# Image 'Image_9986.jpg' moved to subclass folder 'dancing'.
# Image 'Image_9987.jpg' moved to subclass folder 'calling'.
# Image 'Image_9988.jpg' moved to subclass folder 'using_laptop'.
# Image 'Image_9989.jpg' moved to subclass folder 'fighting'.
# Image 'Image_999.jpg' moved to subclass folder 'cycling'.
# Image 'Image_9990.jpg' moved to subclass folder 'calling'.
# Image 'Image_9991.jpg' moved to subclass folder 'sleeping'.
# Image 'Image_9992.jpg' moved to subclass folder 'running'.
# Image 'Image_9993.jpg' moved to subclass folder 'sitting'.
# Image 'Image_9994.jpg' moved to subclass folder 'texting'.
# Image 'Image_9995.jpg' moved to subclass folder 'texting'.
# Image 'Image_9996.jpg' moved to subclass folder 'calling'.
# Image 'Image_9997.jpg' moved to subclass folder 'drinking'.
# Image 'Image_9998.jpg' moved to subclass folder 'drinking'.
# Image 'Image_9999.jpg' moved to subclass folder 'hugging'.

# %%
import os
import random
import shutil
from math import ceil

def move_images(original_directory, duplicate_directory):
    # Iterate through each subdirectory in the original directory
    for subdir in os.listdir(original_directory):
        original_subdir_path = os.path.join(original_directory, subdir)
        duplicate_subdir_path = os.path.join(duplicate_directory, subdir)
        
        # Create the corresponding subdirectory in the duplicate directory
        os.makedirs(duplicate_subdir_path, exist_ok=True)
        
        # Get the list of image files in the original subdirectory
        image_files = [file for file in os.listdir(original_subdir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Calculate the number of images to move (10% of total images rounded up)
        num_images_to_move = ceil(len(image_files) * 0.1)
        
        # Choose a random selection of images to move
        images_to_move = random.sample(image_files, num_images_to_move)
        
        # Move the selected images to the duplicate subdirectory
        for file in images_to_move:
            original_file_path = os.path.join(original_subdir_path, file)
            duplicate_file_path = os.path.join(duplicate_subdir_path, file)
            shutil.move(original_file_path, duplicate_file_path)

    print("Image movement completed successfully.")

# Provide the paths for the original directory and duplicate directory
original_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_TRAIN/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_VALID/"

# Call the function to move the images
move_images(original_directory, duplicate_directory)
# Out:
# Image movement completed successfully.

# %%
import os
import random
import shutil
from math import ceil

def move_images(original_directory, duplicate_directory):
    # Iterate through each subdirectory in the original directory
    for subdir in os.listdir(original_directory):
        original_subdir_path = os.path.join(original_directory, subdir)
        duplicate_subdir_path = os.path.join(duplicate_directory, subdir)
        
        # Create the corresponding subdirectory in the duplicate directory
        os.makedirs(duplicate_subdir_path, exist_ok=True)
        
        # Get the list of image files in the original subdirectory
        image_files = [file for file in os.listdir(original_subdir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Calculate the number of images to move (10% of total images rounded up)
        num_images_to_move = ceil(len(image_files) * 0.1)
        
        # Choose a random selection of images to move
        images_to_move = random.sample(image_files, num_images_to_move)
        
        # Move the selected images to the duplicate subdirectory
        for file in images_to_move:
            original_file_path = os.path.join(original_subdir_path, file)
            duplicate_file_path = os.path.join(duplicate_subdir_path, file)
            shutil.move(original_file_path, duplicate_file_path)

    print("Image movement completed successfully.")

# Provide the paths for the original directory and duplicate directory
original_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_TRAIN/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_TEST/"

# Call the function to move the images
move_images(original_directory, duplicate_directory)
# Out:
# Image movement completed successfully.

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import Image

# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_TRAIN/"

# Data augmentation parameters
augmentation_params = {
    'rotation_range': 20,
    'width_shift_range': 0.2,
    'height_shift_range': 0.2,
    'shear_range': 0.2,
    'zoom_range': 0.2,
    'horizontal_flip': True
}

# Target image size
target_size = (224, 224)

# Iterate through each subdirectory
for subdirectory in os.listdir(main_directory):
    subdirectory_path = os.path.join(main_directory, subdirectory)
    
    if os.path.isdir(subdirectory_path):
        # Create an ImageDataGenerator with augmentation parameters
        datagen = ImageDataGenerator(**augmentation_params)
        
        # Get a list of image files within the subdirectory
        image_files = [filename for filename in os.listdir(subdirectory_path) if os.path.isfile(os.path.join(subdirectory_path, filename))]
        
        # Iterate through each image file and apply data augmentation
        for image_file in image_files:
            image_path = os.path.join(subdirectory_path, image_file)
            
            # Load the image
            image = Image.open(image_path)
            
            # Resize the image to the target size
            image = image.resize(target_size)
            
            # Convert the image to a NumPy array
            image_array = np.array(image)
            
            # Generate augmented image
            augmented_image = datagen.flow(image_array.reshape(1, *image_array.shape), batch_size=1).next()[0].astype(np.uint8)
            
            # Convert augmented image back to PIL image
            augmented_image = Image.fromarray(augmented_image)
            
            # Save the augmented image
            augmented_image_path = os.path.join(subdirectory_path, "augmented_" + image_file)
            augmented_image.save(augmented_image_path)

print("Data augmentation applied successfully!")
# Out:
# Data augmentation applied successfully!

# %%
import os
import numpy as np
import tensorflow as tf
from PIL import Image

# Path of the main directory
main_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_TRAIN/"

# Data augmentation parameters
augmentation_params = {
    'brightness': 0.4,
    'contrast': 1.0,
    'jpeg_quality': [80, 100],
    'saturation': 0.5
}

# Target image size
target_size = (224, 224)

# Iterate through each subdirectory
for subdirectory in os.listdir(main_directory):
    subdirectory_path = os.path.join(main_directory, subdirectory)
    
    if os.path.isdir(subdirectory_path):
        # Get a list of image files within the subdirectory
        image_files = [filename for filename in os.listdir(subdirectory_path) if os.path.isfile(os.path.join(subdirectory_path, filename))]
        
        # Iterate through each image file and apply data augmentation
        for image_file in image_files:
            image_path = os.path.join(subdirectory_path, image_file)
            
            # Load and preprocess the image
            image = Image.open(image_path)
            image_tensor = tf.convert_to_tensor(np.array(image))
            image_tensor = tf.image.resize(image_tensor, target_size)
            image_tensor = tf.cast(image_tensor, tf.float32) / 255.0  # Normalize pixel values
            
            # Apply data augmentation
            augmented_image = tf.image.stateless_random_brightness(image_tensor, max_delta=augmentation_params['brightness'], seed=(1, 2))
            augmented_image = tf.image.stateless_random_contrast(augmented_image, lower=1 - augmentation_params['contrast'], upper=1 + augmentation_params['contrast'], seed=(1, 2))
            augmented_image = tf.image.stateless_random_jpeg_quality(augmented_image, min_jpeg_quality=augmentation_params['jpeg_quality'][0], max_jpeg_quality=augmentation_params['jpeg_quality'][1], seed=(1, 2))
            augmented_image = tf.image.stateless_random_saturation(augmented_image, lower=1 - augmentation_params['saturation'], upper=1 + augmentation_params['saturation'], seed=(1, 2))
            
            # Convert augmented image back to PIL image
            augmented_image = tf.clip_by_value(augmented_image * 255.0, 0.0, 255.0)
            augmented_image = tf.cast(augmented_image, tf.uint8)
            augmented_image = Image.fromarray(augmented_image.numpy())
            
            # Generate a new file name for the augmented image
            augmented_image_file = "col_" + image_file
            
            # Save the augmented image with the new file name
            augmented_image_path = os.path.join(subdirectory_path, augmented_image_file)
            augmented_image.save(augmented_image_path)

# %%
import os
import shutil

def duplicate_directory_structure(source_directory, target_directory):
    # Iterate through all directories and subdirectories in the source directory
    for root, dirs, files in os.walk(source_directory):
        # Get the relative path of the current directory from the source directory
        relative_path = os.path.relpath(root, source_directory)
        
        # Create the corresponding directory in the target directory
        target_subdirectory = os.path.join(target_directory, relative_path)
        os.makedirs(target_subdirectory, exist_ok=True)
        
    print("Directory structure duplicated successfully.")

# Provide the path for the source directory
source_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_TRAIN/"

# Provide the path for the target directory (where you want to duplicate the structure)
target_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_TRAIN_GRAY/"

# Call the function to duplicate the directory structure
duplicate_directory_structure(source_directory, target_directory)
# Out:
# Directory structure duplicated successfully.

# %%
import os
import shutil

def duplicate_directory_structure(source_directory, target_directory):
    # Iterate through all directories and subdirectories in the source directory
    for root, dirs, files in os.walk(source_directory):
        # Get the relative path of the current directory from the source directory
        relative_path = os.path.relpath(root, source_directory)
        
        # Create the corresponding directory in the target directory
        target_subdirectory = os.path.join(target_directory, relative_path)
        os.makedirs(target_subdirectory, exist_ok=True)
        
    print("Directory structure duplicated successfully.")

# Provide the path for the source directory
source_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_VALID/"

# Provide the path for the target directory (where you want to duplicate the structure)
target_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_VALID_GRAY/"

# Call the function to duplicate the directory structure
duplicate_directory_structure(source_directory, target_directory)
# Out:
# Directory structure duplicated successfully.

# %%
import os
import shutil

def duplicate_directory_structure(source_directory, target_directory):
    # Iterate through all directories and subdirectories in the source directory
    for root, dirs, files in os.walk(source_directory):
        # Get the relative path of the current directory from the source directory
        relative_path = os.path.relpath(root, source_directory)
        
        # Create the corresponding directory in the target directory
        target_subdirectory = os.path.join(target_directory, relative_path)
        os.makedirs(target_subdirectory, exist_ok=True)
        
    print("Directory structure duplicated successfully.")

# Provide the path for the source directory
source_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_TEST/"

# Provide the path for the target directory (where you want to duplicate the structure)
target_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_TEST_GRAY/"

# Call the function to duplicate the directory structure
duplicate_directory_structure(source_directory, target_directory)
# Out:
# Directory structure duplicated successfully.

# %%
import os
import cv2
import shutil

def convert_to_grayscale(image_path):
    # Read the image
    image = cv2.imread(image_path)

    # Convert the image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Expand the dimensions to match the shape (224, 224, 1)
    gray_image = gray_image[:, :, None]

    return gray_image

def stack_channels(image_path, gray_image):
    # Read the original image
    original_image = cv2.imread(image_path)

    # Stack the grayscale image channels to create a final image
    final_image = cv2.merge([gray_image, gray_image, gray_image])

    return final_image

def copy_and_convert_images(main_directory, duplicate_directory):
    # Iterate through each subclass directory in the main directory
    for subclass_dir in os.listdir(main_directory):
        subclass_dir_path = os.path.join(main_directory, subclass_dir)
        duplicate_subclass_dir_path = os.path.join(duplicate_directory, subclass_dir)
        
        # Create the corresponding subclass directory in the duplicate directory
        os.makedirs(duplicate_subclass_dir_path, exist_ok=True)
        
        # Get the list of image files in the subclass directory
        image_files = [file for file in os.listdir(subclass_dir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Iterate through each image file
        for file in image_files:
            original_file_path = os.path.join(subclass_dir_path, file)
            duplicate_file_path = os.path.join(duplicate_subclass_dir_path, file)
            
            # Convert the image to grayscale
            gray_image = convert_to_grayscale(original_file_path)
            
            # Stack the grayscale channels to create the final image
            final_image = stack_channels(original_file_path, gray_image)
            
            # Save the final image to the duplicate subclass directory
            cv2.imwrite(duplicate_file_path, final_image)

    print("Image conversion and copying completed successfully.")

# Specify the paths for the main directory and duplicate directory
main_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_TRAIN/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_TRAIN_GRAY/"

# Call the function to copy and convert the images
copy_and_convert_images(main_directory, duplicate_directory)
# Out:
# Image conversion and copying completed successfully.

# %%
import os
import cv2
import shutil

def convert_to_grayscale(image_path):
    # Read the image
    image = cv2.imread(image_path)

    # Convert the image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Expand the dimensions to match the shape (224, 224, 1)
    gray_image = gray_image[:, :, None]

    return gray_image

def stack_channels(image_path, gray_image):
    # Read the original image
    original_image = cv2.imread(image_path)

    # Stack the grayscale image channels to create a final image
    final_image = cv2.merge([gray_image, gray_image, gray_image])

    return final_image

def copy_and_convert_images(main_directory, duplicate_directory):
    # Iterate through each subclass directory in the main directory
    for subclass_dir in os.listdir(main_directory):
        subclass_dir_path = os.path.join(main_directory, subclass_dir)
        duplicate_subclass_dir_path = os.path.join(duplicate_directory, subclass_dir)
        
        # Create the corresponding subclass directory in the duplicate directory
        os.makedirs(duplicate_subclass_dir_path, exist_ok=True)
        
        # Get the list of image files in the subclass directory
        image_files = [file for file in os.listdir(subclass_dir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Iterate through each image file
        for file in image_files:
            original_file_path = os.path.join(subclass_dir_path, file)
            duplicate_file_path = os.path.join(duplicate_subclass_dir_path, file)
            
            # Convert the image to grayscale
            gray_image = convert_to_grayscale(original_file_path)
            
            # Stack the grayscale channels to create the final image
            final_image = stack_channels(original_file_path, gray_image)
            
            # Save the final image to the duplicate subclass directory
            cv2.imwrite(duplicate_file_path, final_image)

    print("Image conversion and copying completed successfully.")

# Specify the paths for the main directory and duplicate directory
main_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_VALID/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_VALID_GRAY/"

# Call the function to copy and convert the images
copy_and_convert_images(main_directory, duplicate_directory)
# Out:
# Image conversion and copying completed successfully.

# %%
import os
import cv2
import shutil

def convert_to_grayscale(image_path):
    # Read the image
    image = cv2.imread(image_path)

    # Convert the image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Expand the dimensions to match the shape (224, 224, 1)
    gray_image = gray_image[:, :, None]

    return gray_image

def stack_channels(image_path, gray_image):
    # Read the original image
    original_image = cv2.imread(image_path)

    # Stack the grayscale image channels to create a final image
    final_image = cv2.merge([gray_image, gray_image, gray_image])

    return final_image

def copy_and_convert_images(main_directory, duplicate_directory):
    # Iterate through each subclass directory in the main directory
    for subclass_dir in os.listdir(main_directory):
        subclass_dir_path = os.path.join(main_directory, subclass_dir)
        duplicate_subclass_dir_path = os.path.join(duplicate_directory, subclass_dir)
        
        # Create the corresponding subclass directory in the duplicate directory
        os.makedirs(duplicate_subclass_dir_path, exist_ok=True)
        
        # Get the list of image files in the subclass directory
        image_files = [file for file in os.listdir(subclass_dir_path) if file.endswith('.jpg') or file.endswith('.png')]
        
        # Iterate through each image file
        for file in image_files:
            original_file_path = os.path.join(subclass_dir_path, file)
            duplicate_file_path = os.path.join(duplicate_subclass_dir_path, file)
            
            # Convert the image to grayscale
            gray_image = convert_to_grayscale(original_file_path)
            
            # Stack the grayscale channels to create the final image
            final_image = stack_channels(original_file_path, gray_image)
            
            # Save the final image to the duplicate subclass directory
            cv2.imwrite(duplicate_file_path, final_image)

    print("Image conversion and copying completed successfully.")

# Specify the paths for the main directory and duplicate directory
main_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_TEST/"
duplicate_directory = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_TEST_GRAY/"

# Call the function to copy and convert the images
copy_and_convert_images(main_directory, duplicate_directory)
# Out:
# Image conversion and copying completed successfully.

# %%
# import shutil

# folder_to_zip = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/GO_TEST_GRAY/sleeping/"
# output_zip = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/Human Action Recognition/test_gray_sleeping"

# shutil.make_archive(output_zip, "zip", folder_to_zip)
# Out:
# 'C:\\Users\\Prasanna P M\\Human Project\\STAND_THE_MAN\\Human Action Recognition\\test_gray_sleeping.zip'

# %%
import shutil

zip_file = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TEST_GRAY_SCALE/test_gray_sleeping.zip"
output_folder = "C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TEST_GRAY_SCALE/sleeping/"

shutil.unpack_archive(zip_file, output_folder)
