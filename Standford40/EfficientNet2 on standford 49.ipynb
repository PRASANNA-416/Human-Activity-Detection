# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow.keras.applications.efficientnet as efn
import tensorflow as tf

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.layers import DepthwiseConv2D
from tensorflow.keras.layers import Add
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Reshape, GlobalAveragePooling2D, Activation,UpSampling2D, AveragePooling2D

# %%
train_path = 'C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TRAIN_GRAY_SCALE/'
valid_path = 'C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/VALID_GRAY_SCALE/'
test_path = 'C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TEST_GRAY_SCALE/'

train_batches = ImageDataGenerator(preprocessing_function=efn.preprocess_input).flow_from_directory(
    directory=train_path, target_size=(260,260), batch_size=32)
# Out:
# Found 55220 images belonging to 49 classes.

# %%
valid_batches = ImageDataGenerator(preprocessing_function=efn.preprocess_input).flow_from_directory(
    directory=valid_path, target_size=(260,260), batch_size=32)
# Out:
# Found 1728 images belonging to 49 classes.

# %%
test_batches = ImageDataGenerator(preprocessing_function=efn.preprocess_input).flow_from_directory(
    directory=test_path, target_size=(260,260), batch_size=32, shuffle=False)
# Out:
# Found 1558 images belonging to 49 classes.

# %%
import tensorflow as tf
efficient = tf.keras.applications.EfficientNetB2()
efficient.summary()
# Out:
# Model: "efficientnetb2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 260, 260, 3) 0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 260, 260, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 260, 260, 3)  7           rescaling[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 261, 261, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Dropout

x = efficient.layers[-2].output
x = Dense(256, activation = 'relu')(x)
output = Dense(units=49, activation='softmax')(x)

model = Model(inputs=efficient.input, outputs=output)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 260, 260, 3) 0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 260, 260, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 260, 260, 3)  7           rescaling[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 261, 261, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 130, 130, 32) 864         stem_conv_pad[0][0]
# ...

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
model.fit(x=train_batches,
            steps_per_epoch=len(train_batches),
            validation_data=valid_batches,
            validation_steps=len(valid_batches),
            epochs=10,
            verbose=1
)
# Out:
# Epoch 1/10
# 1726/1726 [==============================] - 55089s 32s/step - loss: 1.2778 - accuracy: 0.6539 - val_loss: 0.5671 - val_accuracy: 0.8281
# Epoch 2/10
#  167/1726 [=>............................] - ETA: 9:08:41 - loss: 0.4493 - accuracy: 0.8677

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools

# %%
test_labels = test_batches.classes

# %%
predictions = model.predict(x=test_batches)
predicted_labels = np.argmax(predictions, axis=1)

# Calculate the testing accuracy
testing_accuracy = np.mean(predicted_labels == test_labels)

print("Testing Accuracy:", testing_accuracy)
# Out:
# Testing Accuracy: 0.8363286264441592

# %%
model.save_weights('EfficientNetLite2_Standford_gray.h5')

# %%
import tensorflow as tf
efficient = tf.keras.applications.EfficientNetB2(weights = None)
efficient.summary()
# Out:
# Model: "efficientnetb2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 260, 260, 3) 0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 260, 260, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 260, 260, 3)  7           rescaling[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 261, 261, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Dropout

x = efficient.layers[-2].output
x = Dense(256, activation = 'relu')(x)
output = Dense(units=49, activation='softmax')(x)

model = Model(inputs=efficient.input, outputs=output)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 260, 260, 3) 0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 260, 260, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 260, 260, 3)  7           rescaling[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 261, 261, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 130, 130, 32) 864         stem_conv_pad[0][0]
# ...

# %%
model.load_weights('EfficientNetLite2_Standford_gray.h5')

# %%
train_path = 'C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TRAIN/'
valid_path = 'C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/VALID/'

train_batches = ImageDataGenerator(preprocessing_function=efn.preprocess_input).flow_from_directory(
    directory=train_path, target_size=(260,260), batch_size=32)
# Out:
# Found 55220 images belonging to 49 classes.

# %%
valid_batches = ImageDataGenerator(preprocessing_function=efn.preprocess_input).flow_from_directory(
    directory=valid_path, target_size=(260,260), batch_size=32)
# Out:
# Found 1728 images belonging to 49 classes.

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
model.fit(x=train_batches,
            steps_per_epoch=len(train_batches),
            validation_data=valid_batches,
            validation_steps=len(valid_batches),
            epochs=7,
            verbose=1
)
# Out:
# Epoch 1/7
# 1726/1726 [==============================] - 35025s 20s/step - loss: 0.3102 - accuracy: 0.9048 - val_loss: 0.5201 - val_accuracy: 0.8628
# Epoch 2/7
# 1726/1726 [==============================] - 56723s 33s/step - loss: 0.1275 - accuracy: 0.9613 - val_loss: 0.5675 - val_accuracy: 0.8553
# Epoch 3/7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\PRASAN~1\AppData\Local\Temp/ipykernel_940/958024183.py in <module>
# ----> 1 model.fit(x=train_batches,
#       2             steps_per_epoch=len(train_batches),
#       3             validation_data=valid_batches,
#       4             validation_steps=len(valid_batches),
#       5             epochs=7,
#
# ...

# %%
test_path = 'C:/Users/Prasanna P M/Human Project/STAND_THE_MAN/TEST/'

# %%
test_batches = ImageDataGenerator(preprocessing_function=efn.preprocess_input).flow_from_directory(
    directory=test_path, target_size=(260,260), batch_size=32, shuffle=False)
# Out:
# Found 1558 images belonging to 49 classes.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools

# %%
test_labels = test_batches.classes

# %%
predictions = model.predict(x=test_batches)
predicted_labels = np.argmax(predictions, axis=1)

# Calculate the testing accuracy
testing_accuracy = np.mean(predicted_labels == test_labels)

print("Testing Accuracy:", testing_accuracy)
# Out:
# Testing Accuracy: 0.8658536585365854

# %%
model.save_weights('EfficientNetLite2_Standford_rgb.h5')

# %%
def get_file_size(file_path):
    size = os.path.getsize(file_path)
    return size

# %%
def convert_bytes(size, unit=None):
    if unit == "KB":
        return print('File size: ' + str(round(size / 1024, 3)) + ' Kilobytes')
    elif unit == "MB":
        return print('File size: ' + str(round(size / (1024 * 1024), 3)) + ' Megabytes')
    else:
        return print('File size: ' + str(size) + ' bytes')

# %%
TF_LITE_MODEL_FILE_NAME = "EfficientNetLite2_Standford_rgb.tflite"

# %%
tf_lite_converter = tf.lite.TFLiteConverter.from_keras_model(model)
tf_lite_converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
# tf_lite_converter.optimizations = [tf.lite.Optimize.DEFAULT]
# tf_lite_converter.target_spec.supported_types = [tf.float16]
tflite_model = tf_lite_converter.convert()
# Out:
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# INFO:tensorflow:Assets written to: C:\Users\PRASAN~1\AppData\Local\Temp\tmp4zmev9vd\assets
# INFO:tensorflow:Assets written to: C:\Users\PRASAN~1\AppData\Local\Temp\tmp4zmev9vd\assets
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded

# %%
tflite_model_name = TF_LITE_MODEL_FILE_NAME
open(tflite_model_name, "wb").write(tflite_model)
# Out:
# 9309712

# %%
import os
convert_bytes(get_file_size(TF_LITE_MODEL_FILE_NAME), "MB")
# Out:
# File size: 8.878 Megabytes
